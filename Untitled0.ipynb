# %%
import pandas as pd
import os
import glob
import requests
import hashlib
from bs4 import BeautifulSoup
from PIL import Image
from io import BytesIO
from urllib.parse import urlparse
from concurrent.futures import ThreadPoolExecutor, as_completed

# ==== BƯỚC 1: Đọc toàn bộ CSV từ thư mục ====
def read_all_csv_in_folder(folder_path):
    all_files = glob.glob(os.path.join(folder_path, "*.csv"))
    dfs = []
    for file in all_files:
        df = pd.read_csv(file)
        dfs.append(df)
    return pd.concat(dfs, ignore_index=True)

# ==== BƯỚC 2: Tiền xử lý dữ liệu ====
def preprocess_df(df):
    df = df[['article_url', 'article_title', 'article_description', 'clickbait_level']].copy()
    df['label'] = df['clickbait_level'].apply(lambda x: 0 if x in [1, 2] else 1)
    return df

# ==== BƯỚC 3: Tạo tên file ảnh duy nhất ====
def safe_filename_from_url(url):
    h = hashlib.md5(url.encode()).hexdigest()
    return f"{h}.jpg"

# ==== BƯỚC 4: Crawl thumbnail từ HTML ====
def extract_thumbnail_from_html(url):
    try:
        headers = {'User-Agent': 'Mozilla/5.0'}
        response = requests.get(url, headers=headers, timeout=3)
        soup = BeautifulSoup(response.text, "html.parser")
        og_image = soup.find("meta", property="og:image")
        if og_image and og_image.get("content"):
            return og_image["content"]
        first_img = soup.find("img")
        if first_img and first_img.get("src"):
            return first_img["src"]
    except Exception as e:
        print(f"[Thumbnail HTML Error] {url}: {e}")
    return None

# ==== BƯỚC 5: Tải và resize ảnh ====
def download_and_resize_image(image_url, save_dir):
    try:
        os.makedirs(save_dir, exist_ok=True)
        response = requests.get(image_url, timeout=3)
        response.raise_for_status()
        img = Image.open(BytesIO(response.content)).convert("RGB")
        img = img.resize((200, 200))
        filename = safe_filename_from_url(image_url)
        save_path = os.path.join(save_dir, filename)
        img.save(save_path, format="JPEG")
        return save_path
    except Exception as e:
        print(f"[Download Error] {image_url}: {e}")
        return None

# ==== BƯỚC 6: Worker đa luồng cho từng URL ====
def process_single_article(url, save_dir):
    image_url = extract_thumbnail_from_html(url)
    if image_url:
        local_path = download_and_resize_image(image_url, save_dir)
    else:
        local_path = None
    return url, local_path

# ==== BƯỚC 7: Tổng hợp toàn bộ pipeline ====
def process_articles_from_folder(folder_path):
    df = read_all_csv_in_folder(folder_path)
    df = preprocess_df(df)

    thumbnail_dir = "/content/drive/MyDrive/Colab Notebooks/NLP/project/thumbnail"
    results = {}

    # ==== Đa luồng crawl ảnh ====
    with ThreadPoolExecutor(max_workers=10) as executor:
        future_to_url = {executor.submit(process_single_article, url, thumbnail_dir): url for url in df['article_url']}
        for future in as_completed(future_to_url):
            url, thumbnail_path = future.result()
            results[url] = thumbnail_path

    # ==== Gán lại cột thumbnail ====
    df['thumbnail'] = df['article_url'].map(results)

    # ==== Ghi ra file CSV ====
    df_out = df[['article_url', 'article_title', 'article_description', 'thumbnail', 'label']]
    output_path = "/content/drive/MyDrive/Colab Notebooks/NLP/project/processed_update_articles.csv"
    df_out.to_csv(output_path, index=False)
    return df_out

process_articles_from_folder("/content/drive/MyDrive/Colab Notebooks/NLP/project")
# Out:
# [Thumbnail HTML Error] https://www.thesun.ie/health/14450500/visitor-restrictions-mask-mandates-hospitals-flu-outbreak-hse-pressure/: HTTPSConnectionPool(host='www.thesun.ie', port=443): Read timed out. (read timeout=3)
# [Thumbnail HTML Error] https://www.thesun.ie/news/14452967/mass-shooting-amazura-nightclub-queens-new-york/: HTTPSConnectionPool(host='www.thesun.ie', port=443): Read timed out. (read timeout=3)
# [Download Error] data:image/png;base64,...: No connection adapters were found for 'data:image/png;base64,...'
# [Download Error] https://shared.mediahuis.be/pages/skipper.svg: cannot identify image file <_io.BytesIO object at 0x7b0c69bab6f0>
# [Download Error] https://shared.mediahuis.be/pages/skipper.svg: cannot identify image file <_io.BytesIO object at 0x7b0c6adbc400>
# [Download Error] https://www.thesun.ie/wp-content/themes/theirishsun/images/sunmasthead.svg: cannot identify image file <_io.BytesIO object at 0x7b0c6e3bab60>
# [Download Error] https://www.thesun.ie/wp-content/themes/theirishsun/images/sunmasthead.svg: cannot identify image file <_io.BytesIO object at 0x7b0c6d35bb00>
# [Download Error] https://www.thesun.ie/wp-content/themes/theirishsun/images/sunmasthead.svg: cannot identify image file <_io.BytesIO object at 0x7b0c6bbc4810>
# [Download Error] https://www.thesun.ie/wp-content/themes/theirishsun/images/sunmasthead.svg: cannot identify image file <_io.BytesIO object at 0x7b0c6a6988b0>
# [Download Error] https://www.thesun.ie/wp-content/uploads/sites/3/2025/01/Off-Platform-Comp-13.png?strip=all&quality=100&w=1920&h=1080&crop=1: HTTPSConnectionPool(host='www.thesun.ie', port=443): Read timed out. (read timeout=3)
# [Download Error] https://www.thesun.ie/wp-content/themes/theirishsun/images/sunmasthead.svg: cannot identify image file <_io.BytesIO object at 0x7b0c6a012390>
# [Thumbnail HTML Error] https://www.thesun.ie/dear-deidre/14456760/divorce-husband-be-with-man-married-dating-site/: HTTPSConnectionPool(host='www.thesun.ie', port=443): Read timed out. (read timeout=3)
# [Thumbnail HTML Error] https://www.thesun.ie/sport/14464411/what-next-luke-littler-endorsements-world-darts-championship/: HTTPSConnectionPool(host='www.thesun.ie', port=443): Read timed out. (read timeout=3)
# [Thumbnail HTML Error] https://www.thesun.ie/sport/14458198/man-utd-luke-shaw-tiktok-molly-mae-hague/: HTTPSConnectionPool(host='www.thesun.ie', port=443): Read timed out. (read timeout=3)
# [Download Error] https://www.thesun.ie/wp-content/themes/theirishsun/images/sunmasthead.svg: cannot identify image file <_io.BytesIO object at 0x7b0c6c27e7f0>
# [Download Error] https://www.thesun.ie/wp-content/themes/theirishsun/images/sunmasthead.svg: cannot identify image file <_io.BytesIO object at 0x7b0c6b3d33d0>
# [Download Error] https://www.thesun.ie/wp-content/themes/theirishsun/images/sunmasthead.svg: cannot identify image file <_io.BytesIO object at 0x7b0c6cec3560>
# [Thumbnail HTML Error] https://www.irishmirror.ie/sport/soccer/neil-farrugia-decision-future-blow-34416609: HTTPSConnectionPool(host='www.irishmirror.ie', port=443): Read timed out. (read timeout=3)
# [Download Error] https://www.thesun.ie/wp-content/themes/theirishsun/images/sunmasthead.svg: cannot identify image file <_io.BytesIO object at 0x7b0c6d881f80>
# [Thumbnail HTML Error] https://www.thesun.ie/news/14467698/elephant-kill-tourist-washing-thailand/: HTTPSConnectionPool(host='www.thesun.ie', port=443): Read timed out. (read timeout=3)
# [Download Error] https://www.thesun.ie/wp-content/uploads/sites/3/2025/01/newspress-collage-pbetwzx1s-1735560274914.jpg?1735979540&strip=all&quality=100&w=1920&h=1080&crop=1: HTTPSConnectionPool(host='www.thesun.ie', port=443): Read timed out.
# [Download Error] https://img2.thejournal.ie/article/6576801/river/?height=400: 500 Server Error: Internal Server Error for url: https://img2.thejournal.ie/article/6576801/river/?height=400
# [Thumbnail HTML Error] https://www.thesun.ie/news/14473337/kinahan-thomas-nicky-mcconnell-gardai-ira-murder/: HTTPSConnectionPool(host='www.thesun.ie', port=443): Read timed out. (read timeout=3)
# [Download Error] https://www.thesun.ie/wp-content/themes/theirishsun/images/sunmasthead.svg: cannot identify image file <_io.BytesIO object at 0x7b0c67fa1a30>
# [Download Error] https://www.thesun.ie/wp-content/themes/theirishsun/images/sunmasthead.svg: cannot identify image file <_io.BytesIO object at 0x7b0c6c833010>
# [Thumbnail HTML Error] https://www.thesun.ie/tv/14483342/coronation-street-mason-actor-luca-toolan-famous-dad/: HTTPSConnectionPool(host='www.thesun.ie', port=443): Read timed out. (read timeout=3)
# [Thumbnail HTML Error] https://www.thesun.ie/tvandshowbiz/14484535/vogue-williams-spencer-matthews-quits-podcast-four-years/: HTTPSConnectionPool(host='www.thesun.ie', port=443): Read timed out. (read timeout=3)
# [Download Error] https://www.thesun.ie/wp-content/themes/theirishsun/images/sunmasthead.svg: cannot identify image file <_io.BytesIO object at 0x7b0c6a200c70>
# [Thumbnail HTML Error] https://www.thesun.ie/news/14484416/putin-urged-publicly-hang-brits-fighting-ukraine-kremlin-propaganda/: HTTPSConnectionPool(host='www.thesun.ie', port=443): Read timed out. (read timeout=3)
# [Download Error] https://www.thesun.ie/wp-content/themes/theirishsun/images/sunmasthead.svg: cannot identify image file <_io.BytesIO object at 0x7b0c6cbe00e0>
# [Thumbnail HTML Error] https://www.thesun.ie/fabulous/14475481/slept-dads-best-friend-wedding-pregnant/: HTTPSConnectionPool(host='www.thesun.ie', port=443): Read timed out. (read timeout=3)
# [Thumbnail HTML Error] https://www.thesun.ie/fabulous/14515187/struggling-addiction-psychosis-running-christopher-connolly/: HTTPSConnectionPool(host='www.thesun.ie', port=443): Read timed out. (read timeout=3)
# [Download Error] https://i2-prod.irishmirror.ie/incoming/article34277168.ece/ALTERNATES/s1200/0_01JEKYSYWYWHRZC4NK8D8MTBCB.jpg: HTTPSConnectionPool(host='i2-prod.irishmirror.ie', port=443): Read timed out. (read timeout=3)
# [Thumbnail HTML Error] https://www.thesun.ie/royals/14480141/meghan-markle-pal-lilibet-princess-phase-family/: HTTPSConnectionPool(host='www.thesun.ie', port=443): Read timed out. (read timeout=3)
# [Download Error] https://i2-prod.irishmirror.ie/incoming/article34434811.ece/ALTERNATES/s1200/0_JS356070175.jpg: HTTPSConnectionPool(host='i2-prod.irishmirror.ie', port=443): Read timed out. (read timeout=3)
# [Download Error] https://www.thesun.ie/wp-content/uploads/sites/3/2025/01/dk-08-01-love-island_COMP_6f924d.png?strip=all&quality=100&w=1500&h=1000&crop=1: HTTPSConnectionPool(host='www.thesun.ie', port=443): Read timed out. (read timeout=3)
# [Download Error] https://i2-prod.irishmirror.ie/incoming/article34482080.ece/ALTERNATES/s1200/1_Alexander-Isak-of-Newcastle-United.jpg: HTTPSConnectionPool(host='i2-prod.irishmirror.ie', port=443): Read timed out. (read timeout=3)
# [Thumbnail HTML Error] https://www.thesun.ie/tv/14488554/coronation-street-andy-whyment-son-towers-over-dad/: HTTPSConnectionPool(host='www.thesun.ie', port=443): Read timed out. (read timeout=3)
# [Thumbnail HTML Error] https://www.thesun.ie/tvandshowbiz/14488547/zendaya-engagement-tom-holland-proposal/: HTTPSConnectionPool(host='www.thesun.ie', port=443): Read timed out. (read timeout=3)
# [Download Error] https://www.thesun.ie/wp-content/uploads/sites/3/2025/01/dk-06-01-shirley-v2_OP.png?strip=all&quality=100&w=1920&h=1080&crop=1: HTTPSConnectionPool(host='www.thesun.ie', port=443): Read timed out. (read timeout=3)
# [Thumbnail HTML Error] https://www.thesun.ie/sport/14489197/james-mcclean-wife-erin-daughter-emergency-surgery/: HTTPSConnectionPool(host='www.thesun.ie', port=443): Read timed out. (read timeout=3)
# [Thumbnail HTML Error] https://www.thesun.ie/news/14489185/brits-freeze-ice-cold-yellow-warnings-snow/: HTTPSConnectionPool(host='www.thesun.ie', port=443): Read timed out. (read timeout=3)
# [Thumbnail HTML Error] https://www.thesun.ie/tv/14489134/abi-webster-breakdown-mason-murder-coronation-street/: HTTPSConnectionPool(host='www.thesun.ie', port=443): Read timed out. (read timeout=3)
# [Thumbnail HTML Error] https://www.thesun.ie/sport/14489616/var-audio-released-duran-red-card-newcastle/: HTTPSConnectionPool(host='www.thesun.ie', port=443): Read timed out. (read timeout=3)
# [Thumbnail HTML Error] https://www.thesun.ie/tvandshowbiz/14482015/aubrey-plaza-breaks-silence-jeff-baena/: HTTPSConnectionPool(host='www.thesun.ie', port=443): Read timed out. (read timeout=3)
# [Thumbnail HTML Error] https://www.thesun.ie/royals/14483223/letter-princess-diana-prince-william-relationship-harry-before-fallout/: HTTPSConnectionPool(host='www.thesun.ie', port=443): Read timed out. (read timeout=3)
# [Thumbnail HTML Error] https://www.thesun.ie/tv/14483088/axed-coronation-street-colson-smith-secret-plan/: HTTPSConnectionPool(host='www.thesun.ie', port=443): Read timed out. (read timeout=3)
# [Download Error] https://www.thesun.ie/wp-content/themes/theirishsun/images/sunmasthead.svg: cannot identify image file <_io.BytesIO object at 0x7b0c6ba741d0>
# [Thumbnail HTML Error] https://www.thesun.ie/royals/14491004/kate-middleton-clever-trick-stop-women-flirting-prince-william/: HTTPSConnectionPool(host='www.thesun.ie', port=443): Read timed out. (read timeout=3)
# [Thumbnail HTML Error] https://www.thesun.ie/sport/14493018/mikel-arteta-in-doghouse-arsenal-fans-trophy-drought/: HTTPSConnectionPool(host='www.thesun.ie', port=443): Read timed out. (read timeout=3)
# [Download Error] https://www.thesun.ie/wp-content/uploads/sites/3/2025/01/Untitled-design-2025-01-08T132452.741.png?strip=all&quality=100&w=1920&h=1080&crop=1: HTTPSConnectionPool(host='www.thesun.ie', port=443): Read timed out. (read timeout=3)
# [Thumbnail HTML Error] https://www.thesun.ie/motors/14492707/honda-ces-cars-concept-tesla-ev-rival/: HTTPSConnectionPool(host='www.thesun.ie', port=443): Read timed out. (read timeout=3)
# [Thumbnail HTML Error] https://www.thesun.ie/tv/14492685/eastenders-natalie-cassidy-lands-job-away-bbc-soap/: HTTPSConnectionPool(host='www.thesun.ie', port=443): Read timed out. (read timeout=3)
# [Download Error] https://www.thesun.ie/wp-content/themes/theirishsun/images/sunmasthead.svg: cannot identify image file <_io.BytesIO object at 0x7b0c6add09f0>
# [Thumbnail HTML Error] https://www.thesun.ie/motors/14492195/urgent-warning-five-driving-test-centres-close-adverse-weather/: HTTPSConnectionPool(host='www.thesun.ie', port=443): Read timed out. (read timeout=3)
# [Download Error] https://www.thesun.ie/wp-content/uploads/sites/3/2025/01/rb-07-01-stabbing_comp_f14e9f.jpg?strip=all&quality=100&w=1500&h=1000&crop=1: 404 Client Error: Not Found for url: https://www.thesun.ie/wp-content/uploads/sites/3/2025/01/rb-07-01-stabbing_comp_f14e9f.jpg?strip=all&quality=100&w=1500&h=1000&crop=1
# [Thumbnail HTML Error] https://www.thesun.ie/news/10382573/who-eleanor-williams/: HTTPSConnectionPool(host='www.thesun.ie', port=443): Read timed out. (read timeout=3)
# [Thumbnail HTML Error] https://www.thesun.ie/tv/14495680/vicar-of-dibley-stamps/: HTTPSConnectionPool(host='www.thesun.ie', port=443): Read timed out. (read timeout=3)
# [Download Error] https://www.thesun.ie/wp-content/themes/theirishsun/images/sunmasthead.svg: cannot identify image file <_io.BytesIO object at 0x7b0c6d5a6700>
# [Thumbnail HTML Error] https://www.thesun.ie/tvandshowbiz/14493685/keith-duffy-late-dad-death-anniversary-emotional-tribute/: HTTPSConnectionPool(host='www.thesun.ie', port=443): Read timed out. (read timeout=3)
# [Thumbnail HTML Error] https://www.thesun.ie/tv/14494079/coronation-street-shock-arrest-dylan-mason-murder/: HTTPSConnectionPool(host='www.thesun.ie', port=443): Read timed out. (read timeout=3)
# [Thumbnail HTML Error] https://www.thesun.ie/sport/14494067/newcastle-last-trophy-win-drought/: HTTPSConnectionPool(host='www.thesun.ie', port=443): Read timed out. (read timeout=3)
# [Download Error] https://shared.mediahuis.be/pages/skipper.svg: cannot identify image file <_io.BytesIO object at 0x7b0c6c12e700>
# [Thumbnail HTML Error] https://www.thesun.ie/tech/14515834/iphone-emergency-call-quietly-danger-silent-how/: HTTPSConnectionPool(host='www.thesun.ie', port=443): Read timed out. (read timeout=3)
# [Thumbnail HTML Error] https://www.thesun.ie/tv/14500458/coronation-street-itv-cash-crisis-streaming-future/: HTTPSConnectionPool(host='www.thesun.ie', port=443): Read timed out. (read timeout=3)
# [Download Error] https://www.thesun.ie/wp-content/themes/theirishsun/images/sunmasthead.svg: cannot identify image file <_io.BytesIO object at 0x7b0c69d8d580>
# [Thumbnail HTML Error] https://www.thesun.ie/tvandshowbiz/14489300/kerry-katona-swipe-ex-fiance-ryan-not-heartbroken-split/: HTTPSConnectionPool(host='www.thesun.ie', port=443): Read timed out. (read timeout=3)
# [Thumbnail HTML Error] https://www.thesun.ie/royals/14490291/huge-news-meghan-markle-lemonada-new-podcast-spotify/: HTTPSConnectionPool(host='www.thesun.ie', port=443): Read timed out. (read timeout=3)
# [Thumbnail HTML Error] https://www.thesun.ie/news/14490097/aerial-video-la-fires-flames-homes-celebs-fleeing/: HTTPSConnectionPool(host='www.thesun.ie', port=443): Read timed out. (read timeout=3)
# [Thumbnail HTML Error] https://www.thesun.ie/tv/14514122/mel-bs-daughter-phoenix-chi-nepo-baby-speaks-out/: HTTPSConnectionPool(host='www.thesun.ie', port=443): Read timed out. (read timeout=3)
# [Thumbnail HTML Error] https://www.thesun.ie/sport/14622288/ireland-england-jamison-gibson-park-six-nations-laws/: HTTPSConnectionPool(host='www.thesun.ie', port=443): Read timed out. (read timeout=3)
# [Thumbnail HTML Error] https://www.thesun.ie/tv/14491999/watch-maya-jama-tour-south-african-villa-love-island/: HTTPSConnectionPool(host='www.thesun.ie', port=443): Read timed out. (read timeout=3)
# [Thumbnail HTML Error] https://www.thesun.ie/news/14526662/high-iq-spot-deer-optical-illusion/: HTTPSConnectionPool(host='www.thesun.ie', port=443): Read timed out. (read timeout=3)
# [Thumbnail HTML Error] https://www.thesun.ie/fabulous/14486100/fitness-losing-weight-walking-health-challenge-recipe/: HTTPSConnectionPool(host='www.thesun.ie', port=443): Read timed out. (read timeout=3)
# [Thumbnail HTML Error] https://www.thesun.ie/tvandshowbiz/14493440/hollyoaks-jorgie-porter-spotted-first-time-giving-birth/: HTTPSConnectionPool(host='www.thesun.ie', port=443): Read timed out. (read timeout=3)
# [Thumbnail HTML Error] https://www.thesun.ie/health/14492555/urgent-warning-shoppers-food-bosses-allergen-fears-supervalu/: HTTPSConnectionPool(host='www.thesun.ie', port=443): Read timed out. (read timeout=3)
# [Download Error] https://www.thesun.ie/wp-content/themes/theirishsun/images/sunmasthead.svg: cannot identify image file <_io.BytesIO object at 0x7b0c69d4a570>
# [Thumbnail HTML Error] https://www.thesun.ie/sport/14493277/horse-racing-tips-thursday-january-09/: HTTPSConnectionPool(host='www.thesun.ie', port=443): Read timed out. (read timeout=3)
# [Thumbnail HTML Error] https://www.thesun.ie/fabulous/14495103/couple-name-baby-son-lucifer-middle-name/: HTTPSConnectionPool(host='www.thesun.ie', port=443): Read timed out. (read timeout=3)
# [Download Error] https://focus.independent.ie/thumbor/XRwPnaKpB7RN29CtcAMr_9v3mzM=/629x460/smart/prod-mh-ireland/f452df36-26f4-4f9e-8919-de37ef2d3691/6243ae32-dc85-4908-92b6-e9a33a3562c6/c470d83a1c944058a25207b8250c0139.jpg: HTTPSConnectionPool(host='focus.independent.ie', port=443): Read timed out. (read timeout=3)
# [Download Error] https://www.thesun.ie/wp-content/themes/theirishsun/images/sunmasthead.svg: cannot identify image file <_io.BytesIO object at 0x7b0c699fc6d0>
# [Thumbnail HTML Error] https://www.thesun.ie/tv/14503742/maura-higgins-curtis-pritchard-romance-love-island-all-stars/: HTTPSConnectionPool(host='www.thesun.ie', port=443): Read timed out. (read timeout=3)
# [Thumbnail HTML Error] https://www.thesun.ie/fabulous/14490442/parents-run-home-bargains-toy-kids-sale-29p/: HTTPSConnectionPool(host='www.thesun.ie', port=443): Read timed out. (read timeout=3)
# [Download Error] https://focus.independent.ie/thumbor/p73o5nQhWKNSp4L2vAWUKSGanMs=/0x657:2644x2420/629x0/prod-mh-ireland/a95e4263-aa39-4c13-9390-32765d9f02e8/c9412556-295d-439f-b726-5a494d32abca/Ghe9_1iXQAAVfNj.jpg: HTTPSConnectionPool(host='focus.independent.ie', port=443): Read timed out. (read timeout=3)
# [Thumbnail HTML Error] https://www.thesun.ie/tv/14492424/towie-freddie-bentley-split-cheating-boyfriend/: HTTPSConnectionPool(host='www.thesun.ie', port=443): Read timed out. (read timeout=3)
# [Thumbnail HTML Error] https://www.thesun.ie/fabulous/14507725/alison-hammond-make-up-free-selfie-always-be-enough/: HTTPSConnectionPool(host='www.thesun.ie', port=443): Read timed out. (read timeout=3)
# [Thumbnail HTML Error] https://www.thesun.ie/money/14490853/popular-beer-brand-to-file-for-administration/: HTTPSConnectionPool(host='www.thesun.ie', port=443): Read timed out. (read timeout=3)
# [Download Error] https://www.thesun.ie/wp-content/themes/theirishsun/images/sunmasthead.svg: cannot identify image file <_io.BytesIO object at 0x7b0c6d4e8720>
# [Thumbnail HTML Error] https://www.thesun.ie/health/14498014/simple-app-weight-loss-save-60-off/: HTTPSConnectionPool(host='www.thesun.ie', port=443): Read timed out. (read timeout=3)
# [Thumbnail HTML Error] https://www.thesun.ie/news/irish-news/14492591/murder-bag-puppies-dog-killed-dumped-snow-carlow/: HTTPSConnectionPool(host='www.thesun.ie', port=443): Read timed out. (read timeout=3)
# [Thumbnail HTML Error] https://www.thesun.ie/tvandshowbiz/14497540/cheryl-tweedy-stalker-terror-text-messages-flowers/: HTTPSConnectionPool(host='www.thesun.ie', port=443): Read timed out. (read timeout=3)
# [Thumbnail HTML Error] https://www.thesun.ie/sport/14493151/comments-sharlene-mawdsley-social-media-instagram-trolls/: HTTPSConnectionPool(host='www.thesun.ie', port=443): Read timed out. (read timeout=3)
# [Thumbnail HTML Error] https://www.thesun.ie/sport/14622610/horse-racing-tips-templegate-thursday-january-30/: HTTPSConnectionPool(host='www.thesun.ie', port=443): Read timed out. (read timeout=3)
# [Thumbnail HTML Error] https://www.thesun.ie/tv/14499415/naked-attraction-behind-scenes-surprise/: HTTPSConnectionPool(host='www.thesun.ie', port=443): Read timed out. (read timeout=3)
# [Download Error] https://i2-prod.irishmirror.ie/incoming/article34458595.ece/ALTERNATES/s1200/0_01JG1EN9MDH4685GEFWT22BZNN.jpg: HTTPSConnectionPool(host='i2-prod.irishmirror.ie', port=443): Read timed out. (read timeout=3)
# [Thumbnail HTML Error] https://www.thesun.ie/news/14498625/irish-defence-forces-bring-teen-hospital-dialysis-snow/: HTTPSConnectionPool(host='www.thesun.ie', port=443): Read timed out. (read timeout=3)
# [Thumbnail HTML Error] https://www.thesun.ie/sport/14499257/nottingham-forest-girlfriend-wives-premier-league/: HTTPSConnectionPool(host='www.thesun.ie', port=443): Read timed out. (read timeout=3)
# [Thumbnail HTML Error] https://www.thesun.ie/tech/14499085/nintendo-switch-2-leaks-rumours-genki-gamestop/: HTTPSConnectionPool(host='www.thesun.ie', port=443): Read timed out. (read timeout=3)
# [Thumbnail HTML Error] https://www.thesun.ie/news/14495406/newborn-baby-rescued-migrant-dinghy-birth/: HTTPSConnectionPool(host='www.thesun.ie', port=443): Read timed out. (read timeout=3)
# [Thumbnail HTML Error] https://www.thesun.ie/news/14495108/body-man-found-vacant-house-donegal-gardai-investigating-death/: HTTPSConnectionPool(host='www.thesun.ie', port=443): Read timed out. (read timeout=3)
# [Thumbnail HTML Error] https://www.thesun.ie/health/14495148/best-times-drink-coffee-sex-health/: HTTPSConnectionPool(host='www.thesun.ie', port=443): Read timed out. (read timeout=3)
# [Thumbnail HTML Error] https://www.thesun.ie/sport/14509592/man-utd-arsenal-hell-fa-cup-arteta-amorim-liverpool/: HTTPSConnectionPool(host='www.thesun.ie', port=443): Read timed out. (read timeout=3)
# [Thumbnail HTML Error] https://www.thesun.ie/sport/14500677/callum-walsh-vs-dean-sutherland-madison-square-garden/: HTTPSConnectionPool(host='www.thesun.ie', port=443): Read timed out. (read timeout=3)
# [Thumbnail HTML Error] https://www.thesun.ie/dear-deidre/14500831/fiancee-broke-up-after-mother-diagnosed-terminal-cancer/: HTTPSConnectionPool(host='www.thesun.ie', port=443): Read timed out. (read timeout=3)
# [Thumbnail HTML Error] https://www.thesun.ie/tv/14500675/love-island-boss-impossible-stars-fake-relationships/: HTTPSConnectionPool(host='www.thesun.ie', port=443): Read timed out. (read timeout=3)
# [Thumbnail HTML Error] https://www.thesun.ie/sport/14511257/chelsea-morecambe-fa-cup-match-report/: HTTPSConnectionPool(host='www.thesun.ie', port=443): Read timed out. (read timeout=3)
# [Thumbnail HTML Error] https://www.thesun.ie/news/14531612/kamala-harris-word-salad-la-fires/: HTTPSConnectionPool(host='www.thesun.ie', port=443): Read timed out. (read timeout=3)
# [Thumbnail HTML Error] https://www.thesun.ie/news/14508288/child-sexual-abuse-grooming-gangs-police-national-inquiry/: HTTPSConnectionPool(host='www.thesun.ie', port=443): Read timed out. (read timeout=3)
# [Thumbnail HTML Error] https://www.thesun.ie/sport/14534628/snooker-si-jiahui-allen-shot-the-masters/: HTTPSConnectionPool(host='www.thesun.ie', port=443): Read timed out. (read timeout=3)
# [Thumbnail HTML Error] https://www.thesun.ie/news/14512761/dunnes-stores-longford-evacuated-bomb-threat-garda/: HTTPSConnectionPool(host='www.thesun.ie', port=443): Read timed out. (read timeout=3)
# [Thumbnail HTML Error] https://www.thesun.ie/tv/14512858/patsy-palmer-update-house-la-fires-eastenders/: HTTPSConnectionPool(host='www.thesun.ie', port=443): Read timed out. (read timeout=3)
# [Thumbnail HTML Error] https://www.thesun.ie/tv/14534354/linda-nolans-heartbreaking-final-interview/: HTTPSConnectionPool(host='www.thesun.ie', port=443): Read timed out. (read timeout=3)
# [Thumbnail HTML Error] https://www.thesun.ie/tv/14513667/married-at-first-sight-kristina-goodsell-dating-kieran-swipe/: HTTPSConnectionPool(host='www.thesun.ie', port=443): Read timed out. (read timeout=3)
# [Thumbnail HTML Error] https://www.thesun.ie/fabulous/14498498/steven-gerrard-new-team-youngest-celebrity-grandparents/: HTTPSConnectionPool(host='www.thesun.ie', port=443): Read timed out. (read timeout=3)
# [Thumbnail HTML Error] https://www.thesun.ie/royals/14498437/kate-rebellion-queen-birthday-snap-body-language/: HTTPSConnectionPool(host='www.thesun.ie', port=443): Read timed out. (read timeout=3)
# [Download Error] https://www.thesun.ie/wp-content/themes/theirishsun/images/sunmasthead.svg: cannot identify image file <_io.BytesIO object at 0x7b0c6c0a3c90>
# [Thumbnail HTML Error] https://www.thesun.ie/sport/14501663/leinster-vs-la-rochelle-joe-mccarthy-champions-cup/: HTTPSConnectionPool(host='www.thesun.ie', port=443): Read timed out. (read timeout=3)
# [Thumbnail HTML Error] https://www.thesun.ie/sport/14515111/money-nathan-aspinall-luke-littler-darts/: HTTPSConnectionPool(host='www.thesun.ie', port=443): Read timed out. (read timeout=3)
# [Thumbnail HTML Error] https://www.thesun.ie/news/14502717/edwin-castro-malibu-home-destroyed-la-wildfires/: HTTPSConnectionPool(host='www.thesun.ie', port=443): Read timed out. (read timeout=3)
# [Thumbnail HTML Error] https://www.thesun.ie/fabulous/14515071/parents-warning-baby-sling-dangers-son-death/: HTTPSConnectionPool(host='www.thesun.ie', port=443): Read timed out. (read timeout=3)
# [Thumbnail HTML Error] https://www.thesun.ie/fabulous/14504307/lost-lower-belly-fat-five-weeks-five-steps/: HTTPSConnectionPool(host='www.thesun.ie', port=443): Read timed out. (read timeout=3)
# [Thumbnail HTML Error] https://www.thesun.ie/news/14504330/donald-trump-sentencing-stormy-daniels-hush-money-conviction/: HTTPSConnectionPool(host='www.thesun.ie', port=443): Read timed out. (read timeout=3)
# [Thumbnail HTML Error] https://www.thesun.ie/news/14504296/costa-del-sol-hotel-worker-poison-tourists-bleach-buffet/: HTTPSConnectionPool(host='www.thesun.ie', port=443): Read timed out. (read timeout=3)
# [Download Error] https://www.thesun.ie/wp-content/themes/theirishsun/images/sunmasthead.svg: cannot identify image file <_io.BytesIO object at 0x7b0c69dc6cf0>
# [Thumbnail HTML Error] https://www.thesun.ie/tv/14504153/bbc-presenter-shakep-dj-replaced-lifesaving-surgery/: HTTPSConnectionPool(host='www.thesun.ie', port=443): Read timed out. (read timeout=3)
# [Thumbnail HTML Error] https://www.thesun.ie/sport/14503835/callum-simpson-vs-steed-woodall-start-time-tv-stream/: HTTPSConnectionPool(host='www.thesun.ie', port=443): Read timed out. (read timeout=3)
# [Thumbnail HTML Error] https://www.thesun.ie/news/14505651/donald-trump-sentencing-hush-money-case/: HTTPSConnectionPool(host='www.thesun.ie', port=443): Read timed out. (read timeout=3)
# [Thumbnail HTML Error] https://www.thesun.ie/tv/14505523/eastenders-viewers-nigel-bates-blunder-phone/: HTTPSConnectionPool(host='www.thesun.ie', port=443): Read timed out. (read timeout=3)
# [Thumbnail HTML Error] https://www.thesun.ie/news/14516861/irishman-shot-masked-gunmen-france-hospital-rennes/: HTTPSConnectionPool(host='www.thesun.ie', port=443): Read timed out. (read timeout=3)
# [Thumbnail HTML Error] https://www.thesun.ie/sport/14501881/armando-broja-injury-everton-peterborough-fa-cup/: HTTPSConnectionPool(host='www.thesun.ie', port=443): Read timed out. (read timeout=3)
# [Thumbnail HTML Error] https://www.thesun.ie/fabulous/14501833/primark-shoppers-frenzy-dupe-bag-longchamp/: HTTPSConnectionPool(host='www.thesun.ie', port=443): Read timed out. (read timeout=3)
# [Thumbnail HTML Error] https://www.thesun.ie/tech/14501767/britain-tsunami-meteotsunami-water-wave-history/: HTTPSConnectionPool(host='www.thesun.ie', port=443): Read timed out. (read timeout=3)
# [Thumbnail HTML Error] https://www.thesun.ie/tv/14501708/the-traitors-going-same-way-all-reality-shows/: HTTPSConnectionPool(host='www.thesun.ie', port=443): Read timed out. (read timeout=3)
# [Thumbnail HTML Error] https://www.thesun.ie/travel/14507930/trevornick-uk-holiday-park-cornwall-best-in-country/: HTTPSConnectionPool(host='www.thesun.ie', port=443): Read timed out. (read timeout=3)
# [Thumbnail HTML Error] https://www.thesun.ie/news/14508281/met-police-cop-george-floyd-incident/: HTTPSConnectionPool(host='www.thesun.ie', port=443): Read timed out. (read timeout=3)
# [Thumbnail HTML Error] https://www.thesun.ie/fabulous/14518395/dunnes-stores-leopard-print-cardigan-modern-twist-knit-euro/: HTTPSConnectionPool(host='www.thesun.ie', port=443): Read timed out. (read timeout=3)
# [Thumbnail HTML Error] https://www.thesun.ie/royals/14503144/five-unanswered-questions-prince-harrys-spare-two-years-on/: HTTPSConnectionPool(host='www.thesun.ie', port=443): Read timed out. (read timeout=3)
# [Thumbnail HTML Error] https://www.thesun.ie/tv/14518678/watch-bizarre-moment-macy-gray-throws-herself-on-floor/: HTTPSConnectionPool(host='www.thesun.ie', port=443): Read timed out. (read timeout=3)
# [Download Error] https://www.thesun.ie/wp-content/uploads/sites/3/2025/01/Off-Platform-Comp-4-1.png?strip=all&quality=100&w=1920&h=1080&crop=1: HTTPSConnectionPool(host='www.thesun.ie', port=443): Read timed out. (read timeout=3)
# [Thumbnail HTML Error] https://www.thesun.ie/tv/14523261/love-island-all-stars-first-couples-revealed-public-vote/: HTTPSConnectionPool(host='www.thesun.ie', port=443): Read timed out. (read timeout=3)
# [Download Error] https://www.thesun.ie/wp-content/themes/theirishsun/images/sunmasthead.svg: cannot identify image file <_io.BytesIO object at 0x7b0c6c874360>
# [Thumbnail HTML Error] https://www.thesun.ie/tv/14509771/dancing-on-ice-chelsee-healey-biggest-fear-injury-second-baby/: HTTPSConnectionPool(host='www.thesun.ie', port=443): Read timed out. (read timeout=3)
# [Thumbnail HTML Error] https://www.thesun.ie/fabulous/14504554/mum-benefits-money-begging-help/: HTTPSConnectionPool(host='www.thesun.ie', port=443): Read timed out. (read timeout=3)
# [Download Error] https://www.thesun.ie/wp-content/themes/theirishsun/images/sunmasthead.svg: cannot identify image file <_io.BytesIO object at 0x7b0c6b5f62a0>
# [Download Error] https://www.thesun.ie/wp-content/themes/theirishsun/images/sunmasthead.svg: cannot identify image file <_io.BytesIO object at 0x7b0c6da81210>
# [Thumbnail HTML Error] https://www.thesun.ie/news/14525015/ukrainian-marine-survived-russian-jailbreak/: HTTPSConnectionPool(host='www.thesun.ie', port=443): Read timed out. (read timeout=3)
# [Thumbnail HTML Error] https://www.thesun.ie/travel/14529195/largest-indoor-theme-park-europe-new-roller-coaster/: HTTPSConnectionPool(host='www.thesun.ie', port=443): Read timed out. (read timeout=3)
# [Thumbnail HTML Error] https://www.thesun.ie/sport/14524793/dejan-kulusevski-eats-sea-moss-sauna-day-life-tottenham/: HTTPSConnectionPool(host='www.thesun.ie', port=443): Read timed out. (read timeout=3)
# [Download Error] https://i2-prod.irishmirror.ie/sport/soccer/article34472005.ece/ALTERNATES/s1200/0_alex.jpg: HTTPSConnectionPool(host='i2-prod.irishmirror.ie', port=443): Read timed out. (read timeout=3)
# [Thumbnail HTML Error] https://www.thesun.ie/tvandshowbiz/14512307/doctor-who-star-millie-gibson-yellow-bikini-sunshine/: HTTPSConnectionPool(host='www.thesun.ie', port=443): Read timed out. (read timeout=3)
# [Thumbnail HTML Error] https://www.thesun.ie/travel/14506727/new-train-service-irish-landmark-towns-proposed-plans-revealed/: HTTPSConnectionPool(host='www.thesun.ie', port=443): Read timed out. (read timeout=3)
# [Thumbnail HTML Error] https://www.thesun.ie/travel/14541626/aer-lingus-january-sale-europe-uk-us-flights-slashed/: HTTPSConnectionPool(host='www.thesun.ie', port=443): Read timed out. (read timeout=3)
# [Thumbnail HTML Error] https://www.thesun.ie/fabulous/14542514/nan-106-anti-ageing-skincare-make-up-haircare-tips/: HTTPSConnectionPool(host='www.thesun.ie', port=443): Read timed out. (read timeout=3)
# [Thumbnail HTML Error] https://www.thesun.ie/travel/14513239/airline-launching-slimmer-planes/: HTTPSConnectionPool(host='www.thesun.ie', port=443): Read timed out. (read timeout=3)
# [Download Error] https://www.thesun.ie/wp-content/themes/theirishsun/images/sunmasthead.svg: cannot identify image file <_io.BytesIO object at 0x7b0c6c0c76a0>
# [Download Error] https://www.thesun.ie/wp-content/themes/theirishsun/images/sunmasthead.svg: cannot identify image file <_io.BytesIO object at 0x7b0c6b6eca40>
# [Thumbnail HTML Error] https://www.thesun.ie/fabulous/14540889/january-february-wardrobe-outfit-dunnes-stores-smart-euro/: HTTPSConnectionPool(host='www.thesun.ie', port=443): Read timed out. (read timeout=3)
# [Thumbnail HTML Error] https://www.thesun.ie/news/14542394/tiktok-mumfluencer-arrested-poisoning-torturing-baby/: HTTPSConnectionPool(host='www.thesun.ie', port=443): Read timed out. (read timeout=3)
# [Thumbnail HTML Error] https://www.thesun.ie/fabulous/14513361/digital-detox-phones-banned-bullied/: HTTPSConnectionPool(host='www.thesun.ie', port=443): Read timed out. (read timeout=3)
# [Thumbnail HTML Error] https://www.thesun.ie/tvandshowbiz/14541737/lottie-tomlinson-gives-birth-second-child-girl/: HTTPSConnectionPool(host='www.thesun.ie', port=443): Read timed out. (read timeout=3)
# [Thumbnail HTML Error] https://www.thesun.ie/fabulous/14541645/selling-tips-for-vinted-trending-hashtags/: HTTPSConnectionPool(host='www.thesun.ie', port=443): Read timed out. (read timeout=3)
# [Thumbnail HTML Error] https://www.thesun.ie/tv/14513780/dancing-on-ice-star-bloodied-bruised-ashley-banjo/: HTTPSConnectionPool(host='www.thesun.ie', port=443): Read timed out. (read timeout=3)
# [Thumbnail HTML Error] https://www.thesun.ie/fabulous/14509251/woman-perfect-way-fried-eggs-no-oil-taste-better/: HTTPSConnectionPool(host='www.thesun.ie', port=443): Read timed out. (read timeout=3)
# [Thumbnail HTML Error] https://www.thesun.ie/money/14515211/irish-parents-social-welfare-boost-how-to-apply-requirements/: HTTPSConnectionPool(host='www.thesun.ie', port=443): Read timed out. (read timeout=3)
# [Thumbnail HTML Error] https://www.thesun.ie/motors/14515158/new-hypercar-seven-seconds-per-lap-faster-f1-racer/: HTTPSConnectionPool(host='www.thesun.ie', port=443): Read timed out. (read timeout=3)
# [Thumbnail HTML Error] https://www.thesun.ie/tvandshowbiz/14510003/peter-andre-instagram-reunited-mum-thea-parkinsons-alzheimers/: HTTPSConnectionPool(host='www.thesun.ie', port=443): Read timed out. (read timeout=3)
# [Thumbnail HTML Error] https://www.thesun.ie/sport/14509979/leyton-orient-derby-postponed-fa-cup/: HTTPSConnectionPool(host='www.thesun.ie', port=443): Read timed out. (read timeout=3)
# [Download Error] https://www.thesun.ie/wp-content/uploads/sites/3/2025/01/RW-01-11-Samsung-remotev2_OP.png?strip=all&quality=100&w=1920&h=1080&crop=1: HTTPSConnectionPool(host='www.thesun.ie', port=443): Read timed out. (read timeout=3)
# [Download Error] https://shared.mediahuis.be/pages/skipper.svg: cannot identify image file <_io.BytesIO object at 0x7b0c6b5bc770>
# [Thumbnail HTML Error] https://www.thesun.ie/money/14529111/aldi-home-staple-middle-aisle-electric-blanket-cosy/: HTTPSConnectionPool(host='www.thesun.ie', port=443): Read timed out. (read timeout=3)
# [Thumbnail HTML Error] https://www.thesun.ie/sport/14510752/khvicha-kvaratskhelia-napoli-transfer-exit-man-utd-chelsea/: HTTPSConnectionPool(host='www.thesun.ie', port=443): Read timed out. (read timeout=3)
# [Thumbnail HTML Error] https://www.thesun.ie/royals/14510743/prince-william-remarkable-birthday-gesture-kate-royal-expert/: HTTPSConnectionPool(host='www.thesun.ie', port=443): Read timed out. (read timeout=3)
# [Thumbnail HTML Error] https://www.thesun.ie/travel/14510734/spain-city-rarely-visited-top-holiday-food-train-flights/: HTTPSConnectionPool(host='www.thesun.ie', port=443): Read timed out. (read timeout=3)
# [Download Error] https://i2-prod.irishmirror.ie/sport/soccer/article34544840.ece/ALTERNATES/s1200/0_omo.jpg: HTTPSConnectionPool(host='i2-prod.irishmirror.ie', port=443): Read timed out. (read timeout=3)
# [Download Error] https://www.thesun.ie/wp-content/themes/theirishsun/images/sunmasthead.svg: cannot identify image file <_io.BytesIO object at 0x7b0c6d5a5300>
# [Thumbnail HTML Error] https://www.thesun.ie/news/14549382/shamima-begum-return-nigel-farage-isis-death-cult/: HTTPSConnectionPool(host='www.thesun.ie', port=443): Read timed out. (read timeout=3)
# [Thumbnail HTML Error] https://www.thesun.ie/motors/14554208/hidden-pothole-damage-costing-thousands-revealed/: HTTPSConnectionPool(host='www.thesun.ie', port=443): Read timed out. (read timeout=3)
# [Thumbnail HTML Error] https://www.thesun.ie/tv/14554194/clues-the-masked-singer-teeth-kingfisher/: HTTPSConnectionPool(host='www.thesun.ie', port=443): Read timed out. (read timeout=3)
# [Download Error] https://www.thesun.ie/wp-content/themes/theirishsun/images/sunmasthead.svg: cannot identify image file <_io.BytesIO object at 0x7b0c6bbf8090>
# [Thumbnail HTML Error] https://www.thesun.ie/tv/14517117/rte-dwts-doireann-garrihy-look-tonight-style/: HTTPSConnectionPool(host='www.thesun.ie', port=443): Read timed out. (read timeout=3)
# [Download Error] https://www.thesun.ie/wp-content/themes/theirishsun/images/sunmasthead.svg: cannot identify image file <_io.BytesIO object at 0x7b0c69938270>
# [Thumbnail HTML Error] https://www.thesun.ie/news/14530296/south-korean-police-arrest-impeached-president-yoon/: HTTPSConnectionPool(host='www.thesun.ie', port=443): Read timed out. (read timeout=3)
# [Download Error] https://www.thesun.ie/wp-content/themes/theirishsun/images/sunmasthead.svg: cannot identify image file <_io.BytesIO object at 0x7b0c69e09490>
# [Thumbnail HTML Error] https://www.thesun.ie/sport/14519390/man-utd-slapped-fine-fa-cup-arsenal-punishment-melee/: HTTPSConnectionPool(host='www.thesun.ie', port=443): Read timed out. (read timeout=3)
# [Download Error] https://www.thesun.ie/wp-content/themes/theirishsun/images/sunmasthead.svg: cannot identify image file <_io.BytesIO object at 0x7b0c698c4950>
# [Thumbnail HTML Error] https://www.thesun.ie/fabulous/14519030/diy-draught-excluder/: HTTPSConnectionPool(host='www.thesun.ie', port=443): Read timed out. (read timeout=3)
# [Thumbnail HTML Error] https://www.thesun.ie/news/14513944/isis-plotting-prison-breakout-syria-general/: HTTPSConnectionPool(host='www.thesun.ie', port=443): Read timed out. (read timeout=3)
# [Thumbnail HTML Error] https://www.thesun.ie/news/14526000/man-pleads-guilty-monaghan-debs-crash-teens/: HTTPSConnectionPool(host='www.thesun.ie', port=443): Read timed out. (read timeout=3)
# [Thumbnail HTML Error] https://www.thesun.ie/motors/14527200/hyundai-rugged-ev-uk-release-spring/: HTTPSConnectionPool(host='www.thesun.ie', port=443): Read timed out. (read timeout=3)
# [Thumbnail HTML Error] https://www.thesun.ie/travel/14513922/european-unsung-resort-town-cheap-uk-flights/: HTTPSConnectionPool(host='www.thesun.ie', port=443): Read timed out. (read timeout=3)
# [Thumbnail HTML Error] https://www.thesun.ie/travel/14527123/new-disneyland-paris-show-disney-movie/: HTTPSConnectionPool(host='www.thesun.ie', port=443): Read timed out. (read timeout=3)
# [Thumbnail HTML Error] https://www.thesun.ie/tv/14516648/ferne-mccann-tears-daughter-audience-dancing-on-ice/: HTTPSConnectionPool(host='www.thesun.ie', port=443): Read timed out. (read timeout=3)
# [Thumbnail HTML Error] https://www.thesun.ie/sport/14516423/fallon-sherrock-beau-greaves-whitlock-tour-card/: HTTPSConnectionPool(host='www.thesun.ie', port=443): Read timed out. (read timeout=3)
# [Thumbnail HTML Error] https://www.thesun.ie/news/14522568/innocent-dirty-cops-tupac-suspect-keefe-son-rages-interview/: HTTPSConnectionPool(host='www.thesun.ie', port=443): Read timed out. (read timeout=3)
# [Thumbnail HTML Error] https://www.thesun.ie/news/14537836/woman-sneaks-onto-plane-serbia-airport/: HTTPSConnectionPool(host='www.thesun.ie', port=443): Read timed out. (read timeout=3)
# [Thumbnail HTML Error] https://www.thesun.ie/sport/14537743/rugby-super-league-salford-sale-cash-crisis/: HTTPSConnectionPool(host='www.thesun.ie', port=443): Read timed out. (read timeout=3)
# [Thumbnail HTML Error] https://www.thesun.ie/tv/14518097/sam-thompson-break-silence-split-zara-mcdermott/: HTTPSConnectionPool(host='www.thesun.ie', port=443): Read timed out. (read timeout=3)
# [Thumbnail HTML Error] https://www.thesun.ie/tv/14523439/love-islands-harriett-breaks-silence-ronnies-secret-messages-olivia/: HTTPSConnectionPool(host='www.thesun.ie', port=443): Read timed out. (read timeout=3)
# [Download Error] https://shared.mediahuis.be/pages/skipper.svg: cannot identify image file <_io.BytesIO object at 0x7b0c6ba1fe70>
# [Thumbnail HTML Error] https://www.thesun.ie/sport/14514964/luke-humphries-nine-darter-german-exhibition/: HTTPSConnectionPool(host='www.thesun.ie', port=443): Read timed out. (read timeout=3)
# [Thumbnail HTML Error] https://www.thesun.ie/sport/14560530/uk-masters-snooker-delayed-murphy-attacked-wasp-again/: HTTPSConnectionPool(host='www.thesun.ie', port=443): Read timed out. (read timeout=3)
# [Download Error] https://i2-prod.irishmirror.ie/incoming/article34479352.ece/ALTERNATES/s1200/0_GettyImages-2188640310.jpg: HTTPSConnectionPool(host='i2-prod.irishmirror.ie', port=443): Read timed out. (read timeout=3)
# [Thumbnail HTML Error] https://www.thesun.ie/tv/14518210/eastenders-star-new-job-axed-from-bbc-soap/: HTTPSConnectionPool(host='www.thesun.ie', port=443): Read timed out. (read timeout=3)
# [Thumbnail HTML Error] https://www.thesun.ie/uncategorized/14525593/married-at-first-sight-star-reveals-new-boyfriend/: HTTPSConnectionPool(host='www.thesun.ie', port=443): Read timed out. (read timeout=3)
# [Thumbnail HTML Error] https://www.thesun.ie/tv/14525476/strictly-star-bbc-host-england-bankruptcy-companybust/: HTTPSConnectionPool(host='www.thesun.ie', port=443): Read timed out. (read timeout=3)
# [Thumbnail HTML Error] https://www.thesun.ie/fabulous/14525429/dry-clothes-without-tumble-dryer-fast/: HTTPSConnectionPool(host='www.thesun.ie', port=443): Read timed out. (read timeout=3)
# [Thumbnail HTML Error] https://www.thesun.ie/fabulous/14525305/upcycling-chest-drawers-simple-side-hustle/: HTTPSConnectionPool(host='www.thesun.ie', port=443): Read timed out. (read timeout=3)
# [Thumbnail HTML Error] https://www.thesun.ie/health/14525249/supermarket-urgently-recalls-cocktail-sausages-health-risk/: HTTPSConnectionPool(host='www.thesun.ie', port=443): Read timed out. (read timeout=3)
# [Thumbnail HTML Error] https://www.thesun.ie/tv/14515315/dwts-jack-woolley-olympian-high-score/: HTTPSConnectionPool(host='www.thesun.ie', port=443): Read timed out. (read timeout=3)
# [Thumbnail HTML Error] https://www.thesun.ie/news/14519894/moment-fiance-drinks-prosecco-manslaughter-charge-mum-suicide/: HTTPSConnectionPool(host='www.thesun.ie', port=443): Read timed out. (read timeout=3)
# [Thumbnail HTML Error] https://www.thesun.ie/fabulous/14519694/dunelm-borg-heatable-foot-warmer-keep-warm-winter/: HTTPSConnectionPool(host='www.thesun.ie', port=443): Read timed out. (read timeout=3)
# [Thumbnail HTML Error] https://www.thesun.ie/tv/14519523/ricky-gervais-london-mansion-fans-hospital/: HTTPSConnectionPool(host='www.thesun.ie', port=443): Read timed out. (read timeout=3)
# [Thumbnail HTML Error] https://www.thesun.ie/news/14519514/daniel-fordham-fakenham-crystal-meth-dealer-police-custody/: HTTPSConnectionPool(host='www.thesun.ie', port=443): Read timed out. (read timeout=3)
# [Thumbnail HTML Error] https://www.thesun.ie/fabulous/14521943/height-difference-relationships-real-life-dating/: HTTPSConnectionPool(host='www.thesun.ie', port=443): Read timed out. (read timeout=3)
# [Thumbnail HTML Error] https://www.thesun.ie/sport/14521836/tyson-fury-retire-give-up-payday-aj-fight/: HTTPSConnectionPool(host='www.thesun.ie', port=443): Read timed out. (read timeout=3)
# [Download Error] https://www.thesun.ie/wp-content/themes/theirishsun/images/sunmasthead.svg: cannot identify image file <_io.BytesIO object at 0x7b0c698d2750>
# [Thumbnail HTML Error] https://www.thesun.ie/news/14521658/keina-mum-sobs-justice-ex-cleared-manslaughter-suicide/: HTTPSConnectionPool(host='www.thesun.ie', port=443): Read timed out. (read timeout=3)
# [Thumbnail HTML Error] https://www.thesun.ie/fabulous/14543761/dunnes-stores-fluffy-cardigan-cable-knit-pattern-euro/: HTTPSConnectionPool(host='www.thesun.ie', port=443): Read timed out. (read timeout=3)
# [Thumbnail HTML Error] https://www.thesun.ie/sport/14535154/ireland-simon-easterby-joe-schmidt-six-nations-squad/: HTTPSConnectionPool(host='www.thesun.ie', port=443): Read timed out. (read timeout=3)
# [Thumbnail HTML Error] https://www.thesun.ie/sport/14535178/mike-tyson-jake-paul-boxing-new-mansion/: HTTPSConnectionPool(host='www.thesun.ie', port=443): Read timed out. (read timeout=3)
# [Thumbnail HTML Error] https://www.thesun.ie/health/14535130/signs-of-breast-cancer-never-ignore-linda-nolan-dies/: HTTPSConnectionPool(host='www.thesun.ie', port=443): Read timed out. (read timeout=3)
# [Thumbnail HTML Error] https://www.thesun.ie/tv/14529667/all-stars-love-island-free-holiday-casey/: HTTPSConnectionPool(host='www.thesun.ie', port=443): Read timed out. (read timeout=3)
# [Thumbnail HTML Error] https://www.thesun.ie/tv/14528111/emmerdale-joe-tate-swallow-pills-dry/: HTTPSConnectionPool(host='www.thesun.ie', port=443): Read timed out. (read timeout=3)
# [Thumbnail HTML Error] https://www.thesun.ie/news/14520070/man-arrested-assault-dublin-car-park-st-cuthberts-road/: HTTPSConnectionPool(host='www.thesun.ie', port=443): Read timed out. (read timeout=3)
# [Thumbnail HTML Error] https://www.thesun.ie/news/14519149/joseph-brennan-bread-eye-watering-sum-will-death/: HTTPSConnectionPool(host='www.thesun.ie', port=443): Read timed out. (read timeout=3)
# [Thumbnail HTML Error] https://www.thesun.ie/royals/14523535/secret-papers-queen-russian-spy-anthony-blunt/: HTTPSConnectionPool(host='www.thesun.ie', port=443): Read timed out. (read timeout=3)
# [Download Error] https://www.thesun.ie/wp-content/themes/theirishsun/images/sunmasthead.svg: cannot identify image file <_io.BytesIO object at 0x7b0c6e4d80e0>
# [Thumbnail HTML Error] https://www.thesun.ie/news/14530157/journalist-ban-not-naming-sara-sharif-judge/: HTTPSConnectionPool(host='www.thesun.ie', port=443): Read timed out. (read timeout=3)
# [Thumbnail HTML Error] https://www.thesun.ie/news/14530127/ww2-agent-honeytraps-buried-military-honours/: HTTPSConnectionPool(host='www.thesun.ie', port=443): Read timed out. (read timeout=3)
# [Download Error] https://i2-prod.irishmirror.ie/incoming/article34481611.ece/ALTERNATES/s1200/0_GettyImages-1357846232.jpg: HTTPSConnectionPool(host='i2-prod.irishmirror.ie', port=443): Read timed out. (read timeout=3)
# [Thumbnail HTML Error] https://www.thesun.ie/sport/14523844/johnny-kenny-liam-scales-celtic-neil-oriordan/: HTTPSConnectionPool(host='www.thesun.ie', port=443): Read timed out. (read timeout=3)
# [Download Error] https://www.thesun.ie/wp-content/themes/theirishsun/images/sunmasthead.svg: cannot identify image file <_io.BytesIO object at 0x7b0c6ac0f330>
# [Download Error] https://www.thesun.ie/wp-content/themes/theirishsun/images/sunmasthead.svg: cannot identify image file <_io.BytesIO object at 0x7b0c6c6d9da0>
# [Thumbnail HTML Error] https://www.thesun.ie/news/14528092/education-four-steps-lay-foundation-irish-children/: HTTPSConnectionPool(host='www.thesun.ie', port=443): Read timed out. (read timeout=3)
# [Thumbnail HTML Error] https://www.thesun.ie/tv/14531197/daisy-midgeley-exit-storyline-coronation-street-charlotte-jordan/: HTTPSConnectionPool(host='www.thesun.ie', port=443): Read timed out. (read timeout=3)
# [Thumbnail HTML Error] https://evoke.ie/2025/01/19/entertainment/presenter-money-rte: HTTPSConnectionPool(host='evoke.ie', port=443): Read timed out. (read timeout=3)
# [Thumbnail HTML Error] https://www.thesun.ie/tv/14522990/love-island-india-ovie-split/: HTTPSConnectionPool(host='www.thesun.ie', port=443): Read timed out. (read timeout=3)
# [Thumbnail HTML Error] https://www.thesun.ie/sport/14542954/ryan-reynolds-rob-mcelhenney-wrexham-la-equidad/: HTTPSConnectionPool(host='www.thesun.ie', port=443): Read timed out. (read timeout=3)
# [Thumbnail HTML Error] https://www.thesun.ie/tv/14542866/elma-towie-costar-slams-kaz-ronnie-kiss/: HTTPSConnectionPool(host='www.thesun.ie', port=443): Read timed out. (read timeout=3)
# [Download Error] https://i2-prod.irishmirror.ie/incoming/article34496581.ece/ALTERNATES/s1200/0_inpho_02207531-1.jpg: HTTPSConnectionPool(host='i2-prod.irishmirror.ie', port=443): Read timed out. (read timeout=3)
# [Thumbnail HTML Error] https://www.thesun.ie/sport/14633444/england-city-ground-forest-senegal-wembley/: HTTPSConnectionPool(host='www.thesun.ie', port=443): Read timed out. (read timeout=3)
# [Thumbnail HTML Error] https://www.irishmirror.ie/tv/shane-lynch-wanted-destroy-boyzone-34565598: HTTPSConnectionPool(host='www.irishmirror.ie', port=443): Read timed out. (read timeout=3)
# [Thumbnail HTML Error] https://evoke.ie/2025/01/19/entertainment/elaine-andrew-porter-baby-bump: HTTPSConnectionPool(host='evoke.ie', port=443): Read timed out. (read timeout=3)
# [Thumbnail HTML Error] https://www.thesun.ie/sport/14566559/barry-mcguigan-daughter-nika-death-god-family/: HTTPSConnectionPool(host='www.thesun.ie', port=443): Read timed out. (read timeout=3)
# [Thumbnail HTML Error] https://www.thesun.ie/sport/14537889/chelsea-escape-points-deduction-secret-payments-abrahmovich/: HTTPSConnectionPool(host='www.thesun.ie', port=443): Read timed out. (read timeout=3)
# [Download Error] https://www.thesun.ie/wp-content/themes/theirishsun/images/sunmasthead.svg: cannot identify image file <_io.BytesIO object at 0x7b0c6b2f2110>
# [Thumbnail HTML Error] https://www.thesun.ie/tv/14528586/a-place-in-the-sun-awkward-shut-down/: HTTPSConnectionPool(host='www.thesun.ie', port=443): Read timed out. (read timeout=3)
# [Download Error] https://i2-prod.irishmirror.ie/incoming/article34494293.ece/ALTERNATES/s1200/0_An-Ipswich-Town-Football-Club-corner-flag.jpg: HTTPSConnectionPool(host='i2-prod.irishmirror.ie', port=443): Read timed out. (read timeout=3)
# ...
# [Thumbnail HTML Error] https://www.thesun.ie/tv/14713774/unrecognisable-star-90s-sitcom-legend-gregor-fisher/: HTTPSConnectionPool(host='www.thesun.ie', port=443): Read timed out. (read timeout=3)
# [Thumbnail HTML Error] https://www.thesun.ie/fabulous/14712708/dunnes-stores-new-ganni-dupe-spring-cheaper/: HTTPSConnectionPool(host='www.thesun.ie', port=443): Read timed out. (read timeout=3)
# [Thumbnail HTML Error] https://www.thesun.ie/tv/14713659/furious-love-island-fans-complain-to-ofcom/: HTTPSConnectionPool(host='www.thesun.ie', port=443): Read timed out. (read timeout=3)
# [Thumbnail HTML Error] https://www.thesun.ie/health/14713270/brink-of-death-blood-stomach-after-sex/: HTTPSConnectionPool(host='www.thesun.ie', port=443): Read timed out. (read timeout=3)
# [Download Error] https://www.irishexaminer.com/cms_media/module_img/9001/4500835_1_seoimageog_SOCCER_20Everton_20_2022075106.jpg: 503 Server Error: Service Temporarily Unavailable for url: https://www.irishexaminer.com/cms_media/module_img/9001/4500835_1_seoimageog_SOCCER_20Everton_20_2022075106.jpg
# [Thumbnail HTML Error] https://www.thesun.ie/travel/14714084/place-sun-laura-hamilton-kids-holiday-hack-free/: HTTPSConnectionPool(host='www.thesun.ie', port=443): Read timed out. (read timeout=3)
# [Thumbnail HTML Error] https://www.thesun.ie/news/14717672/british-soldier-killed-ukraine/: HTTPSConnectionPool(host='www.thesun.ie', port=443): Read timed out. (read timeout=3)
# [Thumbnail HTML Error] https://www.thesun.ie/news/14717645/escaped-lion-mexico-streets/: HTTPSConnectionPool(host='www.thesun.ie', port=443): Read timed out. (read timeout=3)
# [Thumbnail HTML Error] https://www.thesun.ie/sport/14715459/kai-havertz-injury-update-arsenal-release-statement/: HTTPSConnectionPool(host='www.thesun.ie', port=443): Read timed out. (read timeout=3)
# [Thumbnail HTML Error] https://www.thesun.ie/news/14714902/public-transport-police-arrest-anti-social-behaviour-minister/: HTTPSConnectionPool(host='www.thesun.ie', port=443): Read timed out. (read timeout=3)
# [Thumbnail HTML Error] https://www.thesun.ie/travel/14714721/major-boost-irish-holidaymakers-aer-lingus-exclusive-flight/: HTTPSConnectionPool(host='www.thesun.ie', port=443): Read timed out. (read timeout=3)
# [Download Error] https://www.thesun.ie/wp-content/themes/theirishsun/images/sunmasthead.svg: cannot identify image file <_io.BytesIO object at 0x7b0c6d56e200>
# [Thumbnail HTML Error] https://www.thesun.ie/tv/14715206/rte-donal-skehan-birthday-tribute-dad-hilarious-photo/: HTTPSConnectionPool(host='www.thesun.ie', port=443): Read timed out. (read timeout=3)
# [Thumbnail HTML Error] https://www.thesun.ie/sport/14714943/evan-ferguson-troy-parrott-adam-idah-kevin-kilbane/: HTTPSConnectionPool(host='www.thesun.ie', port=443): Read timed out. (read timeout=3)
# [Thumbnail HTML Error] https://www.thesun.ie/fabulous/14612798/dunnes-stores-fans-divided-molly-mae-dupe-fashion-reveals/: HTTPSConnectionPool(host='www.thesun.ie', port=443): Read timed out. (read timeout=3)
# [Thumbnail HTML Error] https://www.thesun.ie/travel/14721668/tui-brits-holiday-cheaper-destinations-spain-full/: HTTPSConnectionPool(host='www.thesun.ie', port=443): Read timed out. (read timeout=3)
# [Thumbnail HTML Error] https://www.thesun.ie/tv/14721562/pete-wicks-huge-clue-maura-higgins-split/: HTTPSConnectionPool(host='www.thesun.ie', port=443): Read timed out. (read timeout=3)
# [Thumbnail HTML Error] https://www.thesun.ie/news/14718017/ghanaian-tourist-britain-staging-wedding/: HTTPSConnectionPool(host='www.thesun.ie', port=443): Read timed out. (read timeout=3)
# [Thumbnail HTML Error] https://www.thesun.ie/fabulous/14718364/ex-boxer-tommy-fury-cleaning-windows/: HTTPSConnectionPool(host='www.thesun.ie', port=443): Read timed out. (read timeout=3)
# [Thumbnail HTML Error] https://www.thesun.ie/sport/14718217/cathal-cregg-roscommon-forward-davy-burke-enda-smith/: HTTPSConnectionPool(host='www.thesun.ie', port=443): Read timed out. (read timeout=3)
# [Thumbnail HTML Error] https://www.thesun.ie/sport/14718251/alex-ferguson-returns-manager-rossi/: HTTPSConnectionPool(host='www.thesun.ie', port=443): Read timed out. (read timeout=3)
# [Thumbnail HTML Error] https://www.thesun.ie/tv/14719134/emmerdale-nine-favourites-death-drowning-lake/: HTTPSConnectionPool(host='www.thesun.ie', port=443): Read timed out. (read timeout=3)
# [Thumbnail HTML Error] https://www.thesun.ie/news/14719122/schoolgirl-overdosed-mums-meds-after-sexual-assault/: HTTPSConnectionPool(host='www.thesun.ie', port=443): Read timed out. (read timeout=3)
# [Thumbnail HTML Error] https://www.thesun.ie/royals/14718942/another-blow-for-harry-visa/: HTTPSConnectionPool(host='www.thesun.ie', port=443): Read timed out. (read timeout=3)
# [Thumbnail HTML Error] https://www.thesun.ie/fabulous/14718770/renee-zellweger-changing-face-liquid-facelifts-beauty-tool/: HTTPSConnectionPool(host='www.thesun.ie', port=443): Read timed out. (read timeout=3)
# [Thumbnail HTML Error] https://www.thesun.ie/tv/14719406/love-island-host-iain-sirling-predicts-all-stars-winner/: HTTPSConnectionPool(host='www.thesun.ie', port=443): Read timed out. (read timeout=3)
# [Thumbnail HTML Error] https://www.thesun.ie/tv/14719297/ekin-su-brother-arda-claims-love-island-chat-cut/: HTTPSConnectionPool(host='www.thesun.ie', port=443): Read timed out. (read timeout=3)
# [Thumbnail HTML Error] https://www.thesun.ie/tvandshowbiz/14719753/kim-kardashian-marries-tv-star-on-beach-new-drama/: HTTPSConnectionPool(host='www.thesun.ie', port=443): Read timed out. (read timeout=3)
# [Thumbnail HTML Error] https://www.thesun.ie/motors/14723640/ferrari-totally-destroyed-smash-house/: HTTPSConnectionPool(host='www.thesun.ie', port=443): Read timed out. (read timeout=3)
# [Thumbnail HTML Error] https://www.thesun.ie/fabulous/14720924/saturdays-star-clothes-range-scots-store/: HTTPSConnectionPool(host='www.thesun.ie', port=443): Read timed out. (read timeout=3)
# [Thumbnail HTML Error] https://www.thesun.ie/sport/14720938/ian-holloway-football-painting-paulo-di-canio/: HTTPSConnectionPool(host='www.thesun.ie', port=443): Read timed out. (read timeout=3)
# [Thumbnail HTML Error] https://www.thesun.ie/travel/14720805/cotswold-spain-village-vineyards/: HTTPSConnectionPool(host='www.thesun.ie', port=443): Read timed out. (read timeout=3)
# [Download Error] https://focus.independent.ie/thumbor/rxTMLOepKH9XCsHkcH34xRqOy80=/0x0:5225x3483/629x0/prod-mh-ireland/0400201a-3c86-4dd1-93eb-33249f38d4d5/879a9cf9-c5a5-4a2a-8c20-4e42d57a18e2/0400201a-3c86-4dd1-93eb-33249f38d4d5.jpg: HTTPSConnectionPool(host='focus.independent.ie', port=443): Read timed out. (read timeout=3)
# [Thumbnail HTML Error] https://www.thesun.ie/fabulous/14721364/diy-home-transformation-grout-bathroom-floor/: HTTPSConnectionPool(host='www.thesun.ie', port=443): Read timed out. (read timeout=3)
# [Thumbnail HTML Error] https://www.thesun.ie/sport/14721008/man-city-injury-news-manuel-akanji-jack-grealish/: HTTPSConnectionPool(host='www.thesun.ie', port=443): Read timed out. (read timeout=3)
# [Thumbnail HTML Error] https://www.thesun.ie/news/14722062/donald-trump-mugshot-oval-office-hanging-white-house/: HTTPSConnectionPool(host='www.thesun.ie', port=443): Read timed out. (read timeout=3)
# [Thumbnail HTML Error] https://www.thesun.ie/tv/14721351/marian-keyes-keith-duffy-walsh-sisters-rte-series-cast/: HTTPSConnectionPool(host='www.thesun.ie', port=443): Read timed out. (read timeout=3)
# [Thumbnail HTML Error] https://www.thesun.ie/tv/14721808/channel-four-worst-house-street-scarlette-douglas-return/: HTTPSConnectionPool(host='www.thesun.ie', port=443): Read timed out. (read timeout=3)
# [Thumbnail HTML Error] https://www.thesun.ie/fabulous/14726249/dunnes-stores-floral-mesh-dress-polished-cost/: HTTPSConnectionPool(host='www.thesun.ie', port=443): Read timed out. (read timeout=3)
# [Thumbnail HTML Error] https://www.thesun.ie/sport/14727044/arne-slot-liverpool-premier-league-coffee/: HTTPSConnectionPool(host='www.thesun.ie', port=443): Read timed out. (read timeout=3)
# [Thumbnail HTML Error] https://www.thesun.ie/news/14726870/woman-sexually-assaulted-historic-castle-man-arrested-cops/: HTTPSConnectionPool(host='www.thesun.ie', port=443): Read timed out. (read timeout=3)
# [Thumbnail HTML Error] https://www.thesun.ie/sport/14726831/chelsea-gary-neville-board-blast-brighton-defeat/: HTTPSConnectionPool(host='www.thesun.ie', port=443): Read timed out. (read timeout=3)
# [Thumbnail HTML Error] https://www.thesun.ie/tech/14728057/rare-blood-moon-uk-partial-lunar-eclipse-exact-time/: HTTPSConnectionPool(host='www.thesun.ie', port=443): Read timed out. (read timeout=3)
# [Thumbnail HTML Error] https://www.thesun.ie/sport/14728027/sarah-healy-1500m-irish-record-keely-klassic-event/: HTTPSConnectionPool(host='www.thesun.ie', port=443): Read timed out. (read timeout=3)
# [Thumbnail HTML Error] https://www.thesun.ie/tv/14727190/the-masked-singer-crowns-pufferfish-winner-samantha-barks/: HTTPSConnectionPool(host='www.thesun.ie', port=443): Read timed out. (read timeout=3)
# [Thumbnail HTML Error] https://www.thesun.ie/tvandshowbiz/14727094/maura-higgins-cheating-jibe-pete-wicks/: HTTPSConnectionPool(host='www.thesun.ie', port=443): Read timed out. (read timeout=3)
# [Thumbnail HTML Error] https://www.thesun.ie/news/14723975/gardai-murder-investigation-man-stabbed-dublin/: HTTPSConnectionPool(host='www.thesun.ie', port=443): Read timed out. (read timeout=3)
# [Thumbnail HTML Error] https://www.thesun.ie/fabulous/14724525/paint-hack-ceiling-umbrella-stop-drips-done-minutes/: HTTPSConnectionPool(host='www.thesun.ie', port=443): Read timed out. (read timeout=3)
# [Thumbnail HTML Error] https://www.thesun.ie/fabulous/14724421/trolls-ungrateful-moaning-temporary-council-house-too-white-clean/: HTTPSConnectionPool(host='www.thesun.ie', port=443): Read timed out. (read timeout=3)
# [Thumbnail HTML Error] https://www.thesun.ie/news/14724663/canterbury-kent-drinking-behaviour-bad/: HTTPSConnectionPool(host='www.thesun.ie', port=443): Read timed out. (read timeout=3)
# [Thumbnail HTML Error] https://www.thesun.ie/sport/14725096/leandro-trossard-horror-miss-arsenal-leicester/: HTTPSConnectionPool(host='www.thesun.ie', port=443): Read timed out. (read timeout=3)
# [Thumbnail HTML Error] https://www.thesun.ie/news/14725253/boobytrapped-walking-trail-cork-glamire-dog-attacks-fears-ireland/: HTTPSConnectionPool(host='www.thesun.ie', port=443): Read timed out. (read timeout=3)
# [Thumbnail HTML Error] https://www.thesun.ie/tv/14725347/andrew-le-page-moves-out-shared-house-tasha-ghouri/: HTTPSConnectionPool(host='www.thesun.ie', port=443): Read timed out. (read timeout=3)
# [Thumbnail HTML Error] https://www.thesun.ie/sport/14726461/man-utd-gary-neville-ruben-amorim-divock-origi/: HTTPSConnectionPool(host='www.thesun.ie', port=443): Read timed out. (read timeout=3)
# [Thumbnail HTML Error] https://www.thesun.ie/news/14729721/elizabeth-hughes-fury-dermot-griffin-killed-son-free/: HTTPSConnectionPool(host='www.thesun.ie', port=443): Read timed out. (read timeout=3)
# [Thumbnail HTML Error] https://www.thesun.ie/tv/14731061/masked-singers-joel-dommett-gino-dacampo/: HTTPSConnectionPool(host='www.thesun.ie', port=443): Read timed out. (read timeout=3)
# [Thumbnail HTML Error] https://www.thesun.ie/tech/14731041/gmail-users-red-alert-warning-scam-stealing-hacking/: HTTPSConnectionPool(host='www.thesun.ie', port=443): Read timed out. (read timeout=3)
# [Thumbnail HTML Error] https://www.thesun.ie/sport/14732169/kieran-mcgeeney-armagh-donegal-aidan-forker-michael-murphy/: HTTPSConnectionPool(host='www.thesun.ie', port=443): Read timed out. (read timeout=3)
# [Thumbnail HTML Error] https://www.thesun.ie/tvandshowbiz/14728248/rylan-bbc-radio-show-health-issue-richie-anderson/: HTTPSConnectionPool(host='www.thesun.ie', port=443): Read timed out. (read timeout=3)
# [Thumbnail HTML Error] https://www.thesun.ie/news/14726379/danielle-mclaughlin-rape-murder-india-death-penalty/: HTTPSConnectionPool(host='www.thesun.ie', port=443): Read timed out. (read timeout=3)
# [Thumbnail HTML Error] https://www.thesun.ie/tvandshowbiz/14731345/zoe-saldana-pulled-off-camera-swearing-baftas-speech/: HTTPSConnectionPool(host='www.thesun.ie', port=443): Read timed out. (read timeout=3)
# [Thumbnail HTML Error] https://www.thesun.ie/tv/14728491/death-in-paradise-run-its-course-selwyn-exit-hint/: HTTPSConnectionPool(host='www.thesun.ie', port=443): Read timed out. (read timeout=3)
# [Thumbnail HTML Error] https://www.thesun.ie/sport/14728433/kyle-walker-ac-milan-sergio-conceicao-verona/: HTTPSConnectionPool(host='www.thesun.ie', port=443): Read timed out. (read timeout=3)
# [Thumbnail HTML Error] https://www.thesun.ie/sport/14731411/roscommon-monaghan-nfl-division-2-result/: HTTPSConnectionPool(host='www.thesun.ie', port=443): Read timed out. (read timeout=3)
# [Thumbnail HTML Error] https://www.thesun.ie/tv/14731450/love-island-olivia-hawkins-return-swipe-harriett-ronnie/: HTTPSConnectionPool(host='www.thesun.ie', port=443): Read timed out. (read timeout=3)
# [Download Error] https://www.thesun.ie/wp-content/themes/theirishsun/images/sunmasthead.svg: cannot identify image file <_io.BytesIO object at 0x7b0c6ec6b010>
# [Thumbnail HTML Error] https://www.thesun.ie/sport/14728811/troy-deeney-bournemouth-justin-kuivert-gesture-southampton-fan/: HTTPSConnectionPool(host='www.thesun.ie', port=443): Read timed out. (read timeout=3)
# [Thumbnail HTML Error] https://www.thesun.ie/motors/14729037/map-britains-dangerous-driving-hotspots/: HTTPSConnectionPool(host='www.thesun.ie', port=443): Read timed out. (read timeout=3)
# [Thumbnail HTML Error] https://www.thesun.ie/sport/14730546/gary-neville-slams-embarrassing-man-utd-spurs-midfield/: HTTPSConnectionPool(host='www.thesun.ie', port=443): Read timed out. (read timeout=3)
# [Thumbnail HTML Error] https://www.thesun.ie/fabulous/14731985/horoscope-today-mystic-meg-february-17-2025/: HTTPSConnectionPool(host='www.thesun.ie', port=443): Read timed out. (read timeout=3)
# [Thumbnail HTML Error] https://www.thesun.ie/sport/14729492/tottenham-daniel-levy-owner-net-worth/: HTTPSConnectionPool(host='www.thesun.ie', port=443): Read timed out. (read timeout=3)
# [Download Error] https://www.thesun.ie/wp-content/uploads/sites/3/2025/02/RW-12-02-LOVE-ISLAND-LINGERIE_OP.png?strip=all&quality=100&w=1920&h=1080&crop=1: HTTPSConnectionPool(host='www.thesun.ie', port=443): Read timed out. (read timeout=3)
# [Thumbnail HTML Error] https://www.thesun.ie/sport/14736543/tactics-exposed-guardiola-erling-haaland-marmoush-masterclass/: HTTPSConnectionPool(host='www.thesun.ie', port=443): Read timed out. (read timeout=3)
# [Thumbnail HTML Error] https://www.thesun.ie/fabulous/14736389/diy-hack-removing-hard-water-stains-cleaning/: HTTPSConnectionPool(host='www.thesun.ie', port=443): Read timed out. (read timeout=3)
# [Thumbnail HTML Error] https://www.irishmirror.ie/news/irish-news/danielle-mclaughlin-vikat-bhagat-murder-34691046: HTTPSConnectionPool(host='www.irishmirror.ie', port=443): Read timed out. (read timeout=3)
# [Thumbnail HTML Error] https://www.thesun.ie/fabulous/14736661/saved-75k-retire-early-money-tips/: HTTPSConnectionPool(host='www.thesun.ie', port=443): Read timed out. (read timeout=3)
# [Thumbnail HTML Error] https://www.thesun.ie/sport/14732299/pj-scully-laois-westmeath-hurling-league/: HTTPSConnectionPool(host='www.thesun.ie', port=443): Read timed out. (read timeout=3)
# [Thumbnail HTML Error] https://www.thesun.ie/tv/14736932/maya-jama-dress-love-island-all-stars-final/: HTTPSConnectionPool(host='www.thesun.ie', port=443): Read timed out. (read timeout=3)
# [Thumbnail HTML Error] https://www.thesun.ie/sport/14732604/world-cup-hottest-fan-busty-snap-ivana-knoll/: HTTPSConnectionPool(host='www.thesun.ie', port=443): Read timed out. (read timeout=3)
# [Thumbnail HTML Error] https://www.thesun.ie/news/14732958/man-arrested-belfast-asylum-seeker-knifed-death-dublin-appeal/: HTTPSConnectionPool(host='www.thesun.ie', port=443): Read timed out. (read timeout=3)

# %% [markdown]
# **Chạy từ đây**

# %%
import pandas as pd

# Đọc lại file đã cập nhật
df = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/NLP/project/processed_update_articles.csv")

# Điều kiện: cả 3 cột đều không NaN và không rỗng
df_full_rows = df[
    df['article_title'].notna() & (df['article_title'].str.strip() != "") &
    df['article_description'].notna() & (df['article_description'].str.strip() != "") &
    df['thumbnail'].notna() & (df['thumbnail'].str.strip() != "")
]

print(f"Số dòng đầy đủ cả 3 thuộc tính: {len(df_full_rows)} / {len(df)}")
df_full_rows.to_csv("/content/drive/MyDrive/Colab Notebooks/NLP/project/cleaned_articles.csv", index=False)
# Out:
# Số dòng đầy đủ cả 3 thuộc tính: 86294 / 86762

# %%
df_full_rows.head()
# Out:
#                                          article_url  \
# 0  https://www.irishmirror.ie/sport/ufc/conor-mcg...
# 1  https://www.thesun.ie/tv/14450756/claudia-wink...
# 2  https://www.irishmirror.ie/news/irish-news/jud...
# 3  https://www.irishmirror.ie/news/irish-news/iri...
# 4  https://www.irishmirror.ie/news/weird-news/nos...
#
#                                        article_title  \
# 0  Why Conor McGregor quickly deletes so many of ...
# 1  Claudia Winkleman drops big clue over how The ...
# 2  Judge confirms Liam Payne was 'escaping hotel'...
# 3  Lucky Irish Lotto player scoops €1 million pri...
# 4  Nostradamus' terrifying predictions for 2025 -...
#
#                                  article_description  \
# 0  Conor McGregor has made a bit of a habit of qu...
# 1  CLAUDIA Winkleman has shared a big insight int...
# 2  Liam Payne was taken to his room by hotel staf...
# 3  Along with the €1 million prize winner, six lu...
# 4  The famous astrologer Nostradamus predicted a ...
#
#                                            thumbnail  label
# 0  /content/drive/MyDrive/Colab Notebooks/NLP/pro...      1
# 1  /content/drive/MyDrive/Colab Notebooks/NLP/pro...      0
# 2  /content/drive/MyDrive/Colab Notebooks/NLP/pro...      1
# 3  /content/drive/MyDrive/Colab Notebooks/NLP/pro...      0
# 4  /content/drive/MyDrive/Colab Notebooks/NLP/pro...      1

# %%
df_a = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/NLP/project/news_article_sentiments_dataset.csv")
df_b = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/NLP/project/random_sample_news_article_sentiments.csv")

# Chọn đúng 4 cột cần thiết (nếu các file có thêm cột thừa)
columns_needed = ['article_url', 'article_title', 'article_description', 'clickbait_level']
df_a = df_a[columns_needed]
df_b = df_b[columns_needed]

# Ghép lại hai DataFrame
df_merged = pd.concat([df_a, df_b], ignore_index=True)

# %%
sum_45 = df_merged[df_merged['clickbait_level'].isin([4, 5])].shape[0]
print("Tổng số record có clickbait_level là 4 hoặc 5:", sum_45)
# Out:
# Tổng số record có clickbait_level là 4 hoặc 5: 8613

# %%
# Lấy toàn bộ dòng có clickbait_level 4 hoặc 5
df_45 = df_merged[df_merged['clickbait_level'].isin([4, 5])]

# Lấy ngẫu nhiên sum_45 dòng từ level 1
df_1_sampled = df_merged[df_merged['clickbait_level'] == 1].sample(n=sum_45, random_state=42)

# Kết hợp lại thành new_df
new_df = pd.concat([df_45, df_1_sampled], ignore_index=True)

# Giữ lại các dòng trong new_df mà article_url có trong df_full_rows
merged_df = new_df.merge(df_full_rows, on="article_url", how="inner")

# %%
merged_df.columns.tolist()
# Out:
# ['article_url',
#  'article_title_x',
#  'article_description_x',
#  'clickbait_level',
#  'article_title_y',
#  'article_description_y',
#  'thumbnail',
#  'label']

# %%
final_df = merged_df[['article_url', 'article_title_y', 'article_description_y', 'thumbnail', 'label']]
df_full_rows = final_df.copy()

# %%
#final_df.to_csv("/content/drive/MyDrive/Colab Notebooks/NLP/project/cleaned_articles.csv", index=False)

# Điều kiện: cả 3 cột đều không NaN và không rỗng
df_full_rows = df_full_rows[
    df['article_title'].notna() & (df['article_title'].str.strip() != "") &
    df['article_description'].notna() & (df['article_description'].str.strip() != "") &
    df['thumbnail'].notna() & (df['thumbnail'].str.strip() != "")
]

print(f"Số dòng đầy đủ cả 3 thuộc tính: {len(df_full_rows)} / {len(df_full_rows)}")

# Đếm số lượng mỗi giá trị trong cột label
label_counts = df_full_rows['label'].value_counts().sort_index()

# In kết quả
print("Thống kê số lượng label:")
for label, count in label_counts.items():
    print(f"Label {label}: {count} mẫu")
# Out:
# Số dòng đầy đủ cả 3 thuộc tính: 17051 / 17051
# Thống kê số lượng label:
# Label 0: 8551 mẫu
# Label 1: 8500 mẫu
# /tmp/ipython-input-28-3649447135.py:4: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df_full_rows = df_full_rows[

# %%
df_full_rows = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/NLP/project/cleaned_articles.csv")
df_train, df_val, df_test = split_dataset(df_full_rows)

# %% [markdown]
# # ***Multimodal Soft-prompt Tuning Few-shot Classification with Ensemble Learning***

# %%
#1
# !pip install torch_geometric tqdm
# Out:
# Collecting torch_geometric
#   Using cached torch_geometric-2.6.1-py3-none-any.whl.metadata (63 kB)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (4.67.1)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.11/dist-packages (from torch_geometric) (3.11.15)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch_geometric) (2025.3.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch_geometric) (3.1.6)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from torch_geometric) (2.0.2)
# Requirement already satisfied: psutil>=5.8.0 in /usr/local/lib/python3.11/dist-packages (from torch_geometric) (5.9.5)
# Requirement already satisfied: pyparsing in /usr/local/lib/python3.11/dist-packages (from torch_geometric) (3.2.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from torch_geometric) (2.32.3)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->torch_geometric) (2.6.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.11/dist-packages (from aiohttp->torch_geometric) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->torch_geometric) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.11/dist-packages (from aiohttp->torch_geometric) (1.7.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.11/dist-packages (from aiohttp->torch_geometric) (6.6.3)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->torch_geometric) (0.3.2)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->torch_geometric) (1.20.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch_geometric) (3.0.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->torch_geometric) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->torch_geometric) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->torch_geometric) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->torch_geometric) (2025.7.9)
# Requirement already satisfied: typing-extensions>=4.2 in /usr/local/lib/python3.11/dist-packages (from aiosignal>=1.1.2->aiohttp->torch_geometric) (4.14.1)
# Using cached torch_geometric-2.6.1-py3-none-any.whl (1.1 MB)
# Installing collected packages: torch_geometric
# Successfully installed torch_geometric-2.6.1

# %%
#2
# msp_pipeline.py
"""
Multimodal Soft Prompt Tuning (Few-shot + Ensemble + Ablation) – 9-step pipeline
• Self-contained: chỉ cần DataFrame `df_full_rows` (các cột: article_title,
  article_description, thumbnail, label ∈ {0,1}) + GPU/Torch.
"""

# ===== 0. Imports =====
import os, random, numpy as np, pandas as pd, torch, torch.nn as nn
from tqdm import tqdm
from torch.utils.data import Dataset, DataLoader
from torchvision import transforms
from PIL import Image
from sklearn.model_selection import train_test_split
from sklearn.metrics import (accuracy_score, precision_score, recall_score,
                             f1_score, precision_recall_curve, auc)
from transformers import (RobertaTokenizer, RobertaModel,
                          RobertaForMaskedLM, CLIPModel)
from torch_geometric.nn import GATConv
import spacy
import matplotlib.pyplot as plt
import seaborn as sns
from transformers.utils import logging
logging.set_verbosity_error()
import gc


# ===== 1. Data Preparation =====
def prepare_data(df: pd.DataFrame) -> pd.DataFrame:
    df_full_rows = df[
                      df['article_title'].notna() & (df['article_title'].str.strip() != "") &
                      df['article_description'].notna() & (df['article_description'].str.strip() != "") &
                      df['thumbnail'].notna() & (df['thumbnail'].str.strip() != "")
                    ].copy()
    return df_full_rows

def split_dataset(df: pd.DataFrame, seed=42):
    df_trainval, df_test = train_test_split(df, test_size=0.1, stratify=df.label, random_state=seed)
    df_train, df_val = train_test_split(df_trainval, test_size=2/9, stratify=df_trainval.label, random_state=seed)
    return df_train.reset_index(drop=True), df_val.reset_index(drop=True), df_test.reset_index(drop=True)

# ===== 2. Few-shot Sampler =====
def sample_k_shot(df: pd.DataFrame, k: int, seed: int) -> pd.DataFrame:
    rng = np.random.default_rng(seed)
    return (
        df.groupby("label", group_keys=False)
          .apply(lambda x: x.sample(n=k, random_state=rng.integers(1e6)).assign(label=x.name),
                 include_groups=False)
          .reset_index(drop=True)
    )

# ===== 3. Dataset & Dataloaders =====
class ClickbaitDataset(Dataset):
    def __init__(self, df, tokenizer, img_tf):
        self.df, self.tok, self.tf = df.reset_index(drop=True), tokenizer, img_tf
    def __len__(self): return len(self.df)
    def __getitem__(self, idx):
        r = self.df.loc[idx]
        toks = self.tok(r.article_title, r.article_description,
                        padding='max_length', truncation=True,
                        max_length=128, return_tensors='pt')
        try:
            img = Image.open(r.thumbnail).convert('RGB')
        except:                           # nếu lỗi ảnh ⇒ ảnh đen
            img = Image.new('RGB', (224, 224), (0, 0, 0))
        return {"input_ids": toks.input_ids.squeeze(0),
                "attention_mask": toks.attention_mask.squeeze(0),
                "image": self.tf(img),
                "label": torch.tensor(r.label, dtype=torch.float),
                "title": r.article_title}

def create_dataloader(df, tokenizer, transform, bs, shuffle=True, drop_last=True):
    dataset = ClickbaitDataset(df, tokenizer, transform)
    return DataLoader(dataset, batch_size=bs, shuffle=shuffle, drop_last=drop_last, num_workers=8, pin_memory=True)

# ===== 4. Base Blocks =====
# 4-a) Syntactic encoder (GAT over dependency graph)
nlp = spacy.load("en_core_web_sm")
POS2IDX = {t: i for i, t in enumerate(nlp.get_pipe("tagger").labels)}

class SyntacticEncoder(nn.Module):
    def __init__(self):
        super().__init__()
        self.embedding = nn.Embedding(len(POS2IDX), 128)
        self.gat = GATConv(128, 256)
        self.elu = nn.ELU()
        self.project = nn.Linear(256, 768)

    def forward(self, titles):
        device = next(self.parameters()).device
        feats = []
        for text in titles:
            doc = nlp(text)
            edge_index = torch.tensor([(t.i, c.i) for t in doc for c in t.children] or [(0, 0)],
                                      dtype=torch.long).t().to(device)
            pos_ids = torch.tensor([POS2IDX.get(t.tag_, 0) for t in doc], dtype=torch.long).to(device)
            x = self.embedding(pos_ids)
            x = self.gat(x, edge_index)
            x = self.elu(x)
            feats.append(self.project(x.mean(0)))
        return torch.stack(feats)

# 4-b) Soft prompt helper
class SoftPrompt(nn.Module):
    def __init__(self, n, d): super().__init__(); self.p = nn.Parameter(torch.randn(n, d))
    def forward(self, b): return self.p.unsqueeze(0).expand(b, -1, -1)

# 4-c) Prompted text encoder (Roberta-MLM)
class PromptedText(nn.Module):
    def __init__(self, prompt=True):
        super().__init__()
        self.base = RobertaForMaskedLM.from_pretrained('roberta-large') if prompt \
                    else RobertaModel.from_pretrained('roberta-large')
        self.p_len = 5 if prompt else 0
        self.prompt = SoftPrompt(self.p_len, self.base.config.hidden_size) if prompt else None
    def forward(self, ids, mask):
        if self.prompt is None: return self.base(ids, attention_mask=mask).last_hidden_state.mean(1)
        embeds = self.base.roberta.embeddings.word_embeddings(ids)
        p = self.prompt(embeds.size(0))
        embeds = torch.cat([p, embeds], 1)
        m = torch.cat([torch.ones(ids.size(0), self.p_len, device=ids.device), mask], 1)
        out = self.base.roberta(inputs_embeds=embeds, attention_mask=m)
        return (out.last_hidden_state * m.unsqueeze(-1)).sum(1) / (m.sum(1, keepdim=True) + 1e-9)

# 4-d) Prompted image encoder
class PromptedImage(nn.Module):
    def __init__(self):
        super().__init__()
        self.base = CLIPModel.from_pretrained("openai/clip-vit-base-patch32")
        dim = self.base.vision_model.config.hidden_size
        self.prompt = SoftPrompt(5, dim)
        self.conv = nn.Sequential(nn.Conv1d(dim, 256, 1), nn.ReLU(),
                                  nn.AdaptiveAvgPool1d(1))
        self.out = nn.Linear(256, 768)
    def forward(self, img):
        hid = self.base.vision_model(pixel_values=img).last_hidden_state     # [b, seq, d]
        p = self.prompt(hid.size(0)).mean(1).unsqueeze(1)
        h = torch.cat([p, hid], 1).transpose(1, 2)                           # [b, d, seq+1]
        return self.out(self.conv(h).squeeze(-1))

# 4-e) Loss helpers
class FocalLoss(nn.Module):
    def __init__(s, a=1.0, g=2.0): super().__init__(); s.a, s.g = a, g
    def forward(s, logit, y):
        bce = nn.functional.binary_cross_entropy_with_logits(logit, y, reduction='none')
        pt = torch.exp(-bce); return (s.a * (1 - pt)**s.g * bce).mean()

def get_balanced_bce(df, device):
    pos, neg = (df.label == 1).sum(), (df.label == 0).sum()
    return nn.BCEWithLogitsLoss(pos_weight=torch.tensor([neg/pos]).to(device))

# ===== 5. Build variant model factory =====
def build_model(fusion='concat', prompt=True, loss='focal', df_train=None, device='cuda'):
    class MSP(nn.Module):
        def __init__(self):
            super().__init__()
            self.txt = PromptedText(prompt)
            self.img = PromptedImage()
            self.syn = SyntacticEncoder()
            self.tp, self.ip, self.sp = nn.Linear(self.txt.base.config.hidden_size, 256),\
                                        nn.Linear(768, 256), nn.Linear(768, 256)
            if fusion == 'concat':
                self.fuse = nn.Sequential(nn.Linear(256*3, 512), nn.ReLU(),
                                          nn.Dropout(0.3), nn.Linear(512, 1))
            else:                       # gated
                self.gate = nn.Sequential(nn.Linear(256 * 3, 256 * 3), nn.Sigmoid())
                self.fuse = nn.Sequential(nn.Linear(256 * 3, 128), nn.ReLU(),
                                          nn.Dropout(0.3), nn.Linear(128, 1))
        def forward(self, ids, mask, img, titles):
            t = self.tp(self.txt(ids, mask))
            i = self.ip(self.img(img))
            s = self.sp(self.syn(titles))
            cat = torch.cat([t, i, s], 1)
            if fusion == 'concat': out = self.fuse(cat)
            else: out = self.fuse(self.gate(cat) * cat)
            return out.squeeze(-1)
    if loss == 'focal':
        loss_fn = FocalLoss()
    elif loss == 'bce':
        loss_fn = get_balanced_bce(df_train, device)
    else:
        raise ValueError(f"Unsupported loss: {loss}")

    return MSP(), loss_fn

# ===== 6. Variant Train hyper-params =====
VARIANTS = [
    {'bs': 24, 'lr': 5e-4, 'fusion': 'gated',  'loss': 'focal'},
    {'bs': 32, 'lr': 5e-4, 'fusion': 'concat', 'loss': 'focal'},
    {'bs': 32, 'lr': 2e-4, 'fusion': 'gated',  'loss': 'focal'},
    {'bs': 32, 'lr': 5e-4, 'fusion': 'gated',  'loss': 'bce'},
    {'bs': 32, 'lr': 2e-4, 'fusion': 'gated',  'loss': 'focal'},
]
def train_variant(i, df_train, df_val, tok, tfm, dev, save_dir="/content/drive/MyDrive/Colab Notebooks/NLP/project/"):
    os.makedirs(save_dir, exist_ok=True)
    config = VARIANTS[i]
    print(f"Training variant {i}: {config} | ")

    tr_loader = create_dataloader(df_train, tok, tfm, config['bs'], shuffle=True, drop_last=True)
    va_loader = create_dataloader(df_val, tok, tfm, config['bs'], shuffle=False, drop_last=False)

    model, loss_fn = build_model(fusion=config['fusion'], prompt=True, loss=config['loss'],
                                 df_train=df_train, device=dev)
    model.to(dev)
    opt = torch.optim.AdamW(model.parameters(), lr=config['lr'])

    for epoch in range(3):
        model.train()
        loop = tqdm(tr_loader, desc=f"Epoch {epoch+1}/{3}", leave=True)
        for b in loop:
            opt.zero_grad()
            l = model(b['input_ids'].to(dev),
                      b['attention_mask'].to(dev),
                      b['image'].to(dev),
                      b['title']).to(dev)
            loss = loss_fn(l, b['label'].to(dev))
            loss.backward()
            opt.step()
            loop.set_postfix(loss=loss.item())

    # Validation
    model.eval()
    preds, labels = [], []
    for b in tqdm(va_loader, desc=f"Validating...", leave=True):
        with torch.no_grad():
            p = model(b['input_ids'].to(dev),
                      b['attention_mask'].to(dev),
                      b['image'].to(dev),
                      b['title']).sigmoid().cpu()
        preds.append(p)
        labels.append(b['label'])

    pred = (torch.cat(preds) > 0.5).int()
    true = torch.cat(labels)
    acc = accuracy_score(true, pred)
    f1 = f1_score(true, pred)
    print(f" - val_acc={acc:.4f}, f1={f1:.4f}")

    torch.save(model.state_dict(), os.path.join(save_dir, f"variant_{i}.pt"))
    return acc, f1

def load_models(idxs: list, df_train, device='cuda', save_dir="/content/drive/MyDrive/Colab Notebooks/NLP/project/"):
    models = []
    for i in idxs:
        config = VARIANTS[i]
        model, _ = build_model(fusion=config['fusion'], prompt=True, loss=config['loss'],
                               df_train=df_train, device=device)
        model.load_state_dict(torch.load(os.path.join(save_dir, f"variant_{i}.pt"), map_location=device))
        model.to(device)
        model.eval()
        models.append(model)
    return models

# ===== 7. Full Test - Ensemble =====
def full_eval_run(df_test, models, weights, tok, tfm, dev, bs):
    print(f"Running full-set ensemble evaluation...")
    te_loader = create_dataloader(df_test, tok, tfm, bs=bs, shuffle=False, drop_last=False)
    probs = []

    for i, m in enumerate(models):
        m.eval()
        pred = []
        for b in tqdm(te_loader, desc=f"Model {i}/{len(models)-1}", leave=False):
            with torch.no_grad():
                p = m(b['input_ids'].to(dev),
                      b['attention_mask'].to(dev),
                      b['image'].to(dev),
                      b['title']).sigmoid().cpu()
            pred.append(p)
        probs.append(torch.cat(pred))

    # Hard voting
    bin_preds = [(p > 0.5).int() for p in probs]
    votes = sum(p * w for p, w in zip(bin_preds, weights))
    pred = (votes > 0.5).int()

    # Ground-truth
    y = torch.cat([b['label'] for b in te_loader])

    acc = accuracy_score(y, pred)
    f1 = f1_score(y, pred)
    rc = recall_score(y, pred)

    # Soft-voting for PR AUC
    soft_final = sum(p * w for p, w in zip(probs, weights))
    pr, rc_curve, _ = precision_recall_curve(y, soft_final)
    pr_auc = auc(rc_curve, pr)

    print(f"  Full-set → acc={acc:.4f}, f1={f1:.4f}, recall={rc:.4f}, PR-AUC={pr_auc:.4f}")
    return dict(acc=acc, f1=f1, recall=rc, pr_auc=pr_auc)

# ===== 8. Few-shot run + logging =====
def fewshot_run(fewshot_df, models, weights, k, tok, tfm, dev, bs):
    print(f"Running few-shot experiment with k={k}")
    te_loader = create_dataloader(fewshot_df, tok, tfm, bs=bs, shuffle=False, drop_last=False)
    probs = []

    for i, m in enumerate(models):
        m.eval()
        pred = []
        for b in tqdm(te_loader, desc=f"Model {i}/{len(models)-1}", leave=True):
            with torch.no_grad():
                p = m(b['input_ids'].to(dev),
                      b['attention_mask'].to(dev),
                      b['image'].to(dev),
                      b['title']).sigmoid().cpu()
            pred.append(p)
        probs.append(torch.cat(pred))

    bin_preds = [(p > 0.5).int() for p in probs]
    votes = sum(p * w for p, w in zip(bin_preds, weights))
    final = (votes > 0.5).int()
    pred = (final > 0.5).int()
    y = torch.cat([b['label'] for b in te_loader])

    acc = accuracy_score(y, pred)
    f1 = f1_score(y, pred)
    rc = recall_score(y, pred)
    soft_final = sum(p * w for p, w in zip(probs, weights))
    pr, rc_curve, _ = precision_recall_curve(y, soft_final)
    pr_auc = auc(rc_curve, pr)

    print(f"  k={k} → acc={acc:.4f}, f1={f1:.4f}")
    return dict(k=k, acc=acc, f1=f1, recall=rc, pr_auc=pr_auc)



# ===== 10. Visualization helpers (bước 9) =====
def plot_results(results_df):

    # ---- Accuracy vs. k-shot ----
    plt.figure(figsize=(6, 4))
    sns.lineplot(x='k', y='acc', data=results_df, marker='o', linewidth=2)
    plt.title("Accuracy vs. k-shot")
    plt.xlabel("k-shot (samples per class)")
    plt.ylabel("Accuracy")
    plt.grid(True)
    plt.tight_layout()
    plt.show()

    # ---- Heatmap (optional) ----
    if all(c in results_df.columns for c in ['lr', 'bs']):
        pivot = results_df.pivot_table(index="bs", columns="lr", values="acc")
        plt.figure(figsize=(6, 4))
        sns.heatmap(pivot, annot=True, fmt=".2f", cmap="YlGnBu")
        plt.title("Accuracy Heatmap (lr vs. batch size)")
        plt.xlabel("Learning Rate")
        plt.ylabel("Batch Size")
        plt.tight_layout()
        plt.show()



# ===========================

# %%
#3
df_train = pd.read_pickle("/content/drive/MyDrive/Colab Notebooks/NLP/project/df_train.pkl")
df_val = pd.read_pickle("/content/drive/MyDrive/Colab Notebooks/NLP/project/df_val.pkl")
df_test = pd.read_pickle("/content/drive/MyDrive/Colab Notebooks/NLP/project/df_test.pkl")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipython-input-6-1471502587.py in <cell line: 0>()
# ----> 1 df_train = pd.read_pickle("/content/drive/MyDrive/Colab Notebooks/NLP/project/df_train.pkl")
#       2 df_val = pd.read_pickle("/content/drive/MyDrive/Colab Notebooks/NLP/project/df_val.pkl")
#       3 df_test = pd.read_pickle("/content/drive/MyDrive/Colab Notebooks/NLP/project/df_test.pkl")
#
# /usr/local/lib/python3.11/dist-packages/pandas/io/pickle.py in read_pickle(filepath_or_buffer, compression, storage_options)
#     183     """
#     184     excs_to_catch = (AttributeError, ImportError, ModuleNotFoundError, TypeError)
# --> 185     with get_handle(
#     186         filepath_or_buffer,
#     187         "rb",
#
# /usr/local/lib/python3.11/dist-packages/pandas/io/common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     880         else:
#     881             # Binary mode
# --> 882             handle = open(handle, ioargs.mode)
#     883         handles.append(handle)
#     884
#
# FileNotFoundError: [Errno 2] No such file or directory: '/content/drive/MyDrive/Colab Notebooks/NLP/project/df_train.pkl'

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
#4
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
tokenizer = RobertaTokenizer.from_pretrained('roberta-large')
img_tf = transforms.Compose([
        transforms.Resize((224, 224)),
        transforms.ToTensor(),
        transforms.Normalize([0.485, 0.456, 0.406],
                             [0.229, 0.224, 0.225])
    ])
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# tokenizer_config.json:   0%|          | 0.00/25.0 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/899k [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.36M [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/482 [00:00<?, ?B/s]

# %%
#5
train_variant(0, df_train, df_val, tokenizer, img_tf, device)
#need re-train
# Out:
# Training variant 0: {'bs': 24, 'lr': 0.0005, 'fusion': 'concat', 'loss': 'focal'} |
# Epoch 1/3: 100%|██████████| 497/497 [14:23<00:00,  1.74s/it, loss=0.0926]
# Epoch 2/3: 100%|██████████| 497/497 [08:58<00:00,  1.08s/it, loss=0.124]
# Epoch 3/3: 100%|██████████| 497/497 [08:59<00:00,  1.08s/it, loss=0.0736]
# Validating...: 100%|██████████| 143/143 [03:03<00:00,  1.28s/it]
#  - val_acc=0.7921, f1=0.8050
# (0.7920821114369502, 0.8049518569463548)

# %%
#6
train_variant(1, df_train, df_val, tokenizer, img_tf, device)
#need re-train
# Out:
# Training variant 1: {'bs': 24, 'lr': 0.0002, 'fusion': 'gated', 'loss': 'focal'} |
# Epoch 1/3: 100%|██████████| 497/497 [23:16<00:00,  2.81s/it, loss=0.13]
# Epoch 2/3: 100%|██████████| 497/497 [09:26<00:00,  1.14s/it, loss=0.13]
# Epoch 3/3: 100%|██████████| 497/497 [09:26<00:00,  1.14s/it, loss=0.0884]
# Validating...: 100%|██████████| 143/143 [05:40<00:00,  2.38s/it]
#  - val_acc=0.8103, f1=0.8080
# (0.8102639296187684, 0.8079548827545265)

# %%
#7
train_variant(2, df_train, df_val, tokenizer, img_tf, device)
#need re-train
# Out:
# Training variant 2: {'bs': 24, 'lr': 0.0005, 'fusion': 'gated', 'loss': 'focal'} |
# Epoch 1/3: 100%|██████████| 497/497 [26:32<00:00,  3.21s/it, loss=0.0945]
# Epoch 2/3: 100%|██████████| 497/497 [09:17<00:00,  1.12s/it, loss=0.162]
# Epoch 3/3: 100%|██████████| 497/497 [09:13<00:00,  1.11s/it, loss=0.117]
# Validating...: 100%|██████████| 143/143 [05:41<00:00,  2.38s/it]
#  - val_acc=0.7894, f1=0.8038
# (0.7894428152492668, 0.8038251366120218)

# %%
#8
train_variant(3, df_train, df_val, tokenizer, img_tf, device)

# %%
#9
train_variant(4, df_train, df_val, tokenizer, img_tf, device)

# %%
#10
# Sau khi đã train, bạn chọn tay 5 model tốt nhất:
chosen = [0, 1, 2] # change
models = load_models(chosen, df_train, device)
# Out:
# model.safetensors:   0%|          | 0.00/1.42G [00:00<?, ?B/s]
# config.json: 0.00B [00:00, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/605M [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/605M [00:00<?, ?B/s]
# array([0.12612448, 0.77700843, 0.09686708])

# %%
#11
scores = [0.7920821114369502, 0.8102639296187684, 0.7894428152492668] #acc1, acc2, acc3, acc4, acc5

def softmax(x, tau=0.005  ):
    x = np.array(x)
    e = np.exp(x / tau)
    return e / e.sum()
weights = softmax(scores, tau=0.1)
weights
# Out:
# array([0.31512456, 0.37795916, 0.30691628])

# %%
#11
#df_test = pd.read_pickle("/content/drive/MyDrive/Colab Notebooks/NLP/project/df_test.pkl")

full_eval_run(df_test, models, weights, tokenizer, img_tf, device, bs=32)

# %%
#12
results = []
for k in [5, 10, 20]:
    fewshot_df = sample_k_shot(df_test, k=k, seed=42)  # hoặc random seed
    result = fewshot_run(fewshot_df, models, weights, k, tokenizer, img_tf, device, bs=32)
    results.append(result)

results_df = pd.DataFrame(results)
results_df.to_pickle("/content/drive/MyDrive/Colab Notebooks/NLP/project/results.pkl")

# %%
#13
results_df = pd.read_pickle("/content/drive/MyDrive/Colab Notebooks/NLP/project/results.pkl")
display(results_df)
plot_results(results_df)
# Out:
#     k       acc        f1    recall    pr_auc
# 0  20  0.487028  0.507361  0.531435  0.624855
# 1  40  0.514741  0.540480  0.570755  0.649316
